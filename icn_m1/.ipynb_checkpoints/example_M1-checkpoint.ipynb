# %%
from bids import BIDSLayout
import sys
import settings
import pandas as pd
from settings import Settings
import os
import mne_bids
from shutil import copyfile, copy
from mne_bids import write_raw_bids, make_bids_basename
import mne
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import metrics
import numpy as np
import scipy
from scipy import signal
import pybv
import json
import M1_tf_interpolation_BIDS
import time

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, roc_auc_score
from sklearn.ensemble import RandomForestRegressor

# %%
with open('settings/settings.json', 'rb') as f: 
    settings = json.load(f)

# %% [markdown]
# ### loading the GRID

# %%
ecog_grid_left, ecog_grid_right, stn_grid_left, stn_grid_right = \
        M1_tf_interpolation_BIDS.read_grid()
grid_ = [ecog_grid_left, stn_grid_left, ecog_grid_right, stn_grid_right]

# %%
ecog_grid_left = grid_[0]
ecog_grid_right = grid_[2]

fig = plt.figure(dpi=100)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(ecog_grid_left[0,:], ecog_grid_left[1,:],ecog_grid_left[2,:], zdir='z', s=20, c=None, depthshade=True, label='contralateral')
ax.scatter(ecog_grid_right[0,:], ecog_grid_right[1,:],ecog_grid_right[2,:], zdir='z', s=20, c=None, depthshade=True, label='ipsilateral')

ax.view_init(azim=0, elev=90)
plt.legend()
plt.title('grid matrix')
# Out:
# Text(0.5, 0.92, 'grid matrix')

# %%
stn_grid_left = grid_[1]
stn_grid_right = grid_[3]

# %%
fig = plt.figure(dpi=100)
ax = fig.add_subplot(111, projection='3d')
ax.scatter(stn_grid_left[0,:], stn_grid_left[1,:],stn_grid_left[2,:], zdir='z', s=20, c=None, depthshade=True, label='contralateral')
ax.scatter(stn_grid_right[0,:], stn_grid_right[1,:],stn_grid_right[2,:], zdir='z', s=20, c=None, depthshade=True, label='ipsilateral')
ax.view_init(azim=0, elev=90)
plt.legend()
plt.title('STN grid')
# Out:
# Text(0.5, 0.92, 'STN grid')

# %% [markdown]
# ### read BIDS run file

# %%
BIDS_path = settings['BIDS_path']
files = M1_tf_interpolation_BIDS.read_all_vhdr_filenames(BIDS_path)
vhdr_file = files[3]

# %%
vhdr_file
# Out:
# '/Users/hi/Documents/lab_work/BIDS/sub-000/ses-right/eeg/sub-000_ses-right_task-force_run-3_eeg.vhdr'

# %%
bv_raw, ch_names = M1_tf_interpolation_BIDS.read_BIDS_file(vhdr_file)
subject, run, sess = M1_tf_interpolation_BIDS.get_sess_run_subject(vhdr_file)
if 'right' in sess:
    sess_right = True
else:
    sess_right = False

dat_ECOG, dat_STN, dat_MOV, ind_ECOG, ind_STN, ind_MOV, ind_DAT = \
    M1_tf_interpolation_BIDS.get_dat_ECOG_STN(bv_raw, ch_names)
# Out:
# Extracting parameters from /Users/hi/Documents/lab_work/BIDS/sub-000/ses-right/eeg/sub-000_ses-right_task-force_run-3_eeg.vhdr...
# Setting channel info structure...

# %%
ch_names
# Out:
# ['STN_RIGHT_0',
#  'STN_RIGHT_1',
#  'STN_RIGHT_2',
#  'ECOG_RIGHT_0',
#  'ECOG_RIGHT_1',
#  'ECOG_RIGHT_2',
#  'ECOG_RIGHT_3',
#  'ECOG_RIGHT_4',
#  'ECOG_RIGHT_5',
#  'MOV_RIGHT',
#  'MOV_LEFT']

# %% [markdown]
# ### defining filter functions for the run

# %%
fs = M1_tf_interpolation_BIDS.read_run_sampling_frequency(vhdr_file)  # Hz NEEDS to be read out from the BIDS file
f_ranges = settings['f_ranges']

# %%
filter_fun = M1_tf_interpolation_BIDS.calc_band_filters(f_ranges, fs)

# %%
plt.imshow(filter_fun, aspect='auto', cmap='seismic')
plt.colorbar(); plt.clim(-0.1,0.1); plt.xlabel('Time [ms]'); plt.ylabel('Frequency Band')
plt.gca().invert_yaxis()

# %% [markdown]
# ### read the coordinate file for that patient

# %% [markdown]
# Thie get_patient_coordinate functions reads the coordinartes session file, and given the ch_names list from the brainvision file, it returns in a list:
# 1. ECOG coordinates
# 2. STN coordinates
#
#
# Both can be empty(None)

# %%
coord_patient = M1_tf_interpolation_BIDS.get_patient_coordinates(ch_names, \
                                            ind_ECOG, ind_STN, vhdr_file, BIDS_path)

# %%
coord_patient.shape
# Out:
# (2,)

# %%
coord_patient[0].shape
# Out:
# (6, 3)

# %%
coord_patient[1].shape
# Out:
# (3, 3)

# %% [markdown]
# ### Calculate the projection matrix

# %% [markdown]
# There are two projection matrices, 0 - ECOG, 1-STN
#
# Again, both can be empty(None).
# They show the relative weights of every channel for every gridpoint

# %%
max_dist_ECOG = settings['max_dist_ECOG']
max_dist_STN = settings['max_dist_STN']
proj_matrix_run = M1_tf_interpolation_BIDS.calc_projection_matrix(coord_patient, grid_, \
                                        sess_right, max_dist_ECOG, max_dist_STN)

# %%
proj_matrix_run.shape
# Out:
# (2,)

# %%
plt.subplot(121); plt.imshow(proj_matrix_run[0], aspect='auto'); cbar = plt.colorbar(); cbar.set_label('projection weight')
plt.xlabel('channels'); plt.ylabel('grid points'); plt.title('ECOG projection matrix')
plt.subplot(122); plt.imshow(proj_matrix_run[1], aspect='auto'); cbar = plt.colorbar(); cbar.set_label('projection weight')
plt.xlabel('channels'); plt.ylabel('grid points'); plt.title('STN projection matrix')
plt.tight_layout()

# %% [markdown]
# ### defining parameters for online resampling

# %%
line_noise = M1_tf_interpolation_BIDS.read_line_noise(BIDS_path, subject)
normalization_time = settings['normalization_time']
fs_new = settings['fs_new'] 
resample_factor = fs/fs_new
seglengths = np.array([fs/1, fs/2, fs/2, fs/2, \
          fs/2, fs/10, fs/10, fs/10]).astype(int)
normalization_samples = normalization_time*fs_new
new_num_data_points = int((bv_raw.shape[1]/fs)*fs_new)

# downsample_idx states the original brainvision sample indexes are used
downsample_idx = (np.arange(0,new_num_data_points,1)*fs/fs_new).astype(int)
offset_start = int(seglengths[0] / (fs/fs_new))

# %%
offset_start
# Out:
# 10

# %% [markdown]
# ### get active grid points in that session

# %%
arr_act_grid_points = M1_tf_interpolation_BIDS.get_active_grid_points(sess_right, \
                                        ind_MOV, ch_names, proj_matrix_run, grid_)

# %%
plt.plot(arr_act_grid_points)
plt.xlabel('grid point')
# Out:
# Text(0.5, 0, 'grid point')

# %% [markdown]
# ### run online T-F transform, interpolation and resampling

# %%
dat_MOV.shape
# Out:
# (2, 282000)

# %%
normalization_samples = normalization_time*fs_new

# %%
rf_data_median, pf_data_median, mov_median = M1_tf_interpolation_BIDS.real_time_analysis(fs, fs_new, seglengths, f_ranges, grid_, downsample_idx, bv_raw, line_noise, \
                      sess_right, dat_ECOG, dat_STN, dat_MOV, ind_ECOG, ind_STN, ind_MOV, ind_DAT, \
                      filter_fun, proj_matrix_run, arr_act_grid_points, new_num_data_points, ch_names, normalization_samples)
# Out:
# 0.0 s
# 0.1 s
# 0.2 s
# 0.3 s
# 0.4 s
# 0.5 s
# 0.6 s
# 0.7 s
# 0.8 s
# 0.9 s
# 1.0 s
# 1.1 s
# 1.2 s
# 1.3 s
# 1.4 s
# 1.5 s
# 1.6 s
# 1.7 s
# 1.8 s
# 1.9 s
# 2.0 s
# 2.1 s
# 2.2 s
# 2.3 s
# 2.4 s
# 2.5 s
# 2.6 s
# 2.7 s
# 2.8 s
# 2.9 s
# 3.0 s
# 3.1 s
# 3.2 s
# 3.3 s
# 3.4 s
# 3.5 s
# 3.6 s
# 3.7 s
# 3.8 s
# 3.9 s
# 4.0 s
# 4.1 s
# 4.2 s
# 4.3 s
# 4.4 s
# 4.5 s
# 4.6 s
# 4.7 s
# 4.8 s
# 4.9 s
# 5.0 s
# 5.1 s
# 5.2 s
# 5.3 s
# 5.4 s
# 5.5 s
# 5.6 s
# 5.7 s
# 5.8 s
# 5.9 s
# 6.0 s
# 6.1 s
# 6.2 s
# 6.3 s
# 6.4 s
# 6.5 s
# 6.6 s
# 6.7 s
# 6.8 s
# 6.9 s
# 7.0 s
# 7.1 s
# 7.2 s
# 7.3 s
# 7.4 s
# 7.5 s
# 7.6 s
# 7.7 s
# 7.8 s
# 7.9 s
# 8.0 s
# 8.1 s
# 8.2 s
# 8.3 s
# 8.4 s
# 8.5 s
# 8.6 s
# 8.7 s
# 8.8 s
# 8.9 s
# 9.0 s
# 9.1 s
# 9.2 s
# 9.3 s
# 9.4 s
# 9.5 s
# 9.6 s
# 9.7 s
# 9.8 s
# 9.9 s
# 10.0 s
# 10.1 s
# 10.2 s
# 10.3 s
# 10.4 s
# 10.5 s
# 10.6 s
# 10.7 s
# 10.8 s
# 10.9 s
# 11.0 s
# 11.1 s
# 11.2 s
# 11.3 s
# 11.4 s
# 11.5 s
# 11.6 s
# 11.7 s
# 11.8 s
# 11.9 s
# 12.0 s
# 12.1 s
# 12.2 s
# 12.3 s
# 12.4 s
# 12.5 s
# 12.6 s
# 12.7 s
# 12.8 s
# 12.9 s
# 13.0 s
# 13.1 s
# 13.2 s
# 13.3 s
# 13.4 s
# 13.5 s
# 13.6 s
# 13.7 s
# 13.8 s
# 13.9 s
# 14.0 s
# 14.1 s
# 14.2 s
# 14.3 s
# 14.4 s
# 14.5 s
# 14.6 s
# 14.7 s
# 14.8 s
# 14.9 s
# 15.0 s
# 15.1 s
# 15.2 s
# 15.3 s
# 15.4 s
# 15.5 s
# 15.6 s
# 15.7 s
# 15.8 s
# 15.9 s
# 16.0 s
# 16.1 s
# 16.2 s
# 16.3 s
# 16.4 s
# 16.5 s
# 16.6 s
# 16.7 s
# 16.8 s
# 16.9 s
# 17.0 s
# 17.1 s
# 17.2 s
# 17.3 s
# 17.4 s
# 17.5 s
# 17.6 s
# 17.7 s
# 17.8 s
# 17.9 s
# 18.0 s
# 18.1 s
# 18.2 s
# 18.3 s
# 18.4 s
# 18.5 s
# 18.6 s
# 18.7 s
# 18.8 s
# 18.9 s
# 19.0 s
# 19.1 s
# 19.2 s
# 19.3 s
# 19.4 s
# 19.5 s
# 19.6 s
# 19.7 s
# 19.8 s
# 19.9 s
# 20.0 s
# 20.1 s
# 20.2 s
# 20.3 s
# 20.4 s
# 20.5 s
# 20.6 s
# 20.7 s
# 20.8 s
# 20.9 s
# 21.0 s
# 21.1 s
# 21.2 s
# 21.3 s
# 21.4 s
# 21.5 s
# 21.6 s
# 21.7 s
# 21.8 s
# 21.9 s
# 22.0 s
# 22.1 s
# 22.2 s
# 22.3 s
# 22.4 s
# 22.5 s
# 22.6 s
# 22.7 s
# 22.8 s
# 22.9 s
# 23.0 s
# 23.1 s
# 23.2 s
# 23.3 s
# 23.4 s
# 23.5 s
# 23.6 s
# 23.7 s
# 23.8 s
# 23.9 s
# 24.0 s
# 24.1 s
# 24.2 s
# 24.3 s
# 24.4 s
# 24.5 s
# 24.6 s
# 24.7 s
# 24.8 s
# 24.9 s
# 25.0 s
# 25.1 s
# 25.2 s
# 25.3 s
# 25.4 s
# 25.5 s
# 25.6 s
# 25.7 s
# 25.8 s
# 25.9 s
# 26.0 s
# 26.1 s
# 26.2 s
# 26.3 s
# 26.4 s
# 26.5 s
# 26.6 s
# 26.7 s
# 26.8 s
# 26.9 s
# 27.0 s
# 27.1 s
# 27.2 s
# 27.3 s
# 27.4 s
# 27.5 s
# 27.6 s
# 27.7 s
# 27.8 s
# 27.9 s
# 28.0 s
# 28.1 s
# 28.2 s
# 28.3 s
# 28.4 s
# 28.5 s
# 28.6 s
# 28.7 s
# 28.8 s
# 28.9 s
# 29.0 s
# 29.1 s
# 29.2 s
# 29.3 s
# 29.4 s
# 29.5 s
# 29.6 s
# 29.7 s
# 29.8 s
# 29.9 s
# 30.0 s
# 30.1 s
# 30.2 s
# 30.3 s
# 30.4 s
# 30.5 s
# 30.6 s
# 30.7 s
# 30.8 s
# 30.9 s
# 31.0 s
# 31.1 s
# 31.2 s
# 31.3 s
# 31.4 s
# 31.5 s
# 31.6 s
# 31.7 s
# 31.8 s
# 31.9 s
# 32.0 s
# 32.1 s
# 32.2 s
# 32.3 s
# 32.4 s
# 32.5 s
# 32.6 s
# 32.7 s
# 32.8 s
# 32.9 s
# 33.0 s
# 33.1 s
# 33.2 s
# 33.3 s
# 33.4 s
# 33.5 s
# 33.6 s
# 33.7 s
# 33.8 s
# 33.9 s
# 34.0 s
# 34.1 s
# 34.2 s
# 34.3 s
# 34.4 s
# 34.5 s
# 34.6 s
# 34.7 s
# 34.8 s
# 34.9 s
# 35.0 s
# 35.1 s
# 35.2 s
# 35.3 s
# 35.4 s
# 35.5 s
# 35.6 s
# 35.7 s
# 35.8 s
# 35.9 s
# 36.0 s
# 36.1 s
# 36.2 s
# 36.3 s
# 36.4 s
# 36.5 s
# 36.6 s
# 36.7 s
# 36.8 s
# 36.9 s
# 37.0 s
# 37.1 s
# 37.2 s
# 37.3 s
# 37.4 s
# 37.5 s
# 37.6 s
# 37.7 s
# 37.8 s
# 37.9 s
# 38.0 s
# 38.1 s
# 38.2 s
# 38.3 s
# 38.4 s
# 38.5 s
# 38.6 s
# 38.7 s
# 38.8 s
# 38.9 s
# 39.0 s
# 39.1 s
# 39.2 s
# 39.3 s
# 39.4 s
# 39.5 s
# 39.6 s
# 39.7 s
# 39.8 s
# 39.9 s
# 40.0 s
# 40.1 s
# 40.2 s
# 40.3 s
# 40.4 s
# 40.5 s
# 40.6 s
# 40.7 s
# 40.8 s
# 40.9 s
# 41.0 s
# 41.1 s
# 41.2 s
# 41.3 s
# 41.4 s
# 41.5 s
# 41.6 s
# 41.7 s
# 41.8 s
# 41.9 s
# 42.0 s
# 42.1 s
# 42.2 s
# 42.3 s
# 42.4 s
# 42.5 s
# 42.6 s
# 42.7 s
# 42.8 s
# 42.9 s
# 43.0 s
# 43.1 s
# 43.2 s
# 43.3 s
# 43.4 s
# 43.5 s
# 43.6 s
# 43.7 s
# 43.8 s
# 43.9 s
# 44.0 s
# 44.1 s
# 44.2 s
# 44.3 s
# 44.4 s
# 44.5 s
# 44.6 s
# 44.7 s
# 44.8 s
# 44.9 s
# 45.0 s
# 45.1 s
# 45.2 s
# 45.3 s
# 45.4 s
# 45.5 s
# 45.6 s
# 45.7 s
# 45.8 s
# 45.9 s
# 46.0 s
# 46.1 s
# 46.2 s
# 46.3 s
# 46.4 s
# 46.5 s
# 46.6 s
# 46.7 s
# 46.8 s
# 46.9 s
# 47.0 s
# 47.1 s
# 47.2 s
# 47.3 s
# 47.4 s
# 47.5 s
# 47.6 s
# 47.7 s
# 47.8 s
# 47.9 s
# 48.0 s
# 48.1 s
# 48.2 s
# 48.3 s
# 48.4 s
# 48.5 s
# 48.6 s
# 48.7 s
# 48.8 s
# 48.9 s
# 49.0 s
# 49.1 s
# 49.2 s
# 49.3 s
# 49.4 s
# 49.5 s
# 49.6 s
# 49.7 s
# 49.8 s
# 49.9 s
# 50.0 s
# 50.1 s
# 50.2 s
# 50.3 s
# 50.4 s
# 50.5 s
# 50.6 s
# 50.7 s
# 50.8 s
# 50.9 s
# 51.0 s
# 51.1 s
# 51.2 s
# 51.3 s
# 51.4 s
# 51.5 s
# 51.6 s
# 51.7 s
# 51.8 s
# 51.9 s
# 52.0 s
# 52.1 s
# 52.2 s
# 52.3 s
# 52.4 s
# 52.5 s
# 52.6 s
# 52.7 s
# 52.8 s
# 52.9 s
# 53.0 s
# 53.1 s
# 53.2 s
# 53.3 s
# 53.4 s
# 53.5 s
# 53.6 s
# 53.7 s
# 53.8 s
# 53.9 s
# 54.0 s
# 54.1 s
# 54.2 s
# 54.3 s
# 54.4 s
# 54.5 s
# 54.6 s
# 54.7 s
# 54.8 s
# 54.9 s
# 55.0 s
# 55.1 s
# 55.2 s
# 55.3 s
# 55.4 s
# 55.5 s
# 55.6 s
# 55.7 s
# 55.8 s
# 55.9 s
# 56.0 s
# 56.1 s
# 56.2 s
# 56.3 s
# 56.4 s
# 56.5 s
# 56.6 s
# 56.7 s
# 56.8 s
# 56.9 s
# 57.0 s
# 57.1 s
# 57.2 s
# 57.3 s
# 57.4 s
# 57.5 s
# 57.6 s
# 57.7 s
# 57.8 s
# 57.9 s
# 58.0 s
# 58.1 s
# 58.2 s
# 58.3 s
# 58.4 s
# 58.5 s
# 58.6 s
# 58.7 s
# 58.8 s
# 58.9 s
# 59.0 s
# 59.1 s
# 59.2 s
# 59.3 s
# 59.4 s
# 59.5 s
# 59.6 s
# 59.7 s
# 59.8 s
# 59.9 s
# 60.0 s
# 60.1 s
# 60.2 s
# 60.3 s
# 60.4 s
# 60.5 s
# 60.6 s
# 60.7 s
# 60.8 s
# 60.9 s
# 61.0 s
# 61.1 s
# 61.2 s
# 61.3 s
# 61.4 s
# 61.5 s
# 61.6 s
# 61.7 s
# 61.8 s
# 61.9 s
# 62.0 s
# 62.1 s
# 62.2 s
# 62.3 s
# 62.4 s
# 62.5 s
# 62.6 s
# 62.7 s
# 62.8 s
# 62.9 s
# 63.0 s
# 63.1 s
# 63.2 s
# 63.3 s
# 63.4 s
# 63.5 s
# 63.6 s
# 63.7 s
# 63.8 s
# 63.9 s
# 64.0 s
# 64.1 s
# 64.2 s
# 64.3 s
# 64.4 s
# 64.5 s
# 64.6 s
# 64.7 s
# 64.8 s
# 64.9 s
# 65.0 s
# 65.1 s
# 65.2 s
# 65.3 s
# 65.4 s
# 65.5 s
# 65.6 s
# 65.7 s
# 65.8 s
# 65.9 s
# 66.0 s
# 66.1 s
# 66.2 s
# 66.3 s
# 66.4 s
# 66.5 s
# 66.6 s
# 66.7 s
# 66.8 s
# 66.9 s
# 67.0 s
# 67.1 s
# 67.2 s
# 67.3 s
# 67.4 s
# 67.5 s
# 67.6 s
# 67.7 s
# 67.8 s
# 67.9 s
# 68.0 s
# 68.1 s
# 68.2 s
# 68.3 s
# 68.4 s
# 68.5 s
# 68.6 s
# 68.7 s
# 68.8 s
# 68.9 s
# 69.0 s
# 69.1 s
# 69.2 s
# 69.3 s
# 69.4 s
# 69.5 s
# 69.6 s
# 69.7 s
# 69.8 s
# 69.9 s
# 70.0 s
# 70.1 s
# 70.2 s
# 70.3 s
# 70.4 s
# 70.5 s
# 70.6 s
# 70.7 s
# 70.8 s
# 70.9 s
# 71.0 s
# 71.1 s
# 71.2 s
# 71.3 s
# 71.4 s
# 71.5 s
# 71.6 s
# 71.7 s
# 71.8 s
# 71.9 s
# 72.0 s
# 72.1 s
# 72.2 s
# 72.3 s
# 72.4 s
# 72.5 s
# 72.6 s
# 72.7 s
# 72.8 s
# 72.9 s
# 73.0 s
# 73.1 s
# 73.2 s
# 73.3 s
# 73.4 s
# 73.5 s
# 73.6 s
# 73.7 s
# 73.8 s
# 73.9 s
# 74.0 s
# 74.1 s
# 74.2 s
# 74.3 s
# 74.4 s
# 74.5 s
# 74.6 s
# 74.7 s
# 74.8 s
# 74.9 s
# 75.0 s
# 75.1 s
# 75.2 s
# 75.3 s
# 75.4 s
# 75.5 s
# 75.6 s
# 75.7 s
# 75.8 s
# 75.9 s
# 76.0 s
# 76.1 s
# 76.2 s
# 76.3 s
# 76.4 s
# 76.5 s
# 76.6 s
# 76.7 s
# 76.8 s
# 76.9 s
# 77.0 s
# 77.1 s
# 77.2 s
# 77.3 s
# 77.4 s
# 77.5 s
# 77.6 s
# 77.7 s
# 77.8 s
# 77.9 s
# 78.0 s
# 78.1 s
# 78.2 s
# 78.3 s
# 78.4 s
# 78.5 s
# 78.6 s
# 78.7 s
# 78.8 s
# 78.9 s
# 79.0 s
# 79.1 s
# 79.2 s
# 79.3 s
# 79.4 s
# 79.5 s
# 79.6 s
# 79.7 s
# 79.8 s
# 79.9 s
# 80.0 s
# 80.1 s
# 80.2 s
# 80.3 s
# 80.4 s
# 80.5 s
# 80.6 s
# 80.7 s
# 80.8 s
# 80.9 s
# 81.0 s
# 81.1 s
# 81.2 s
# 81.3 s
# 81.4 s
# 81.5 s
# 81.6 s
# 81.7 s
# 81.8 s
# 81.9 s
# 82.0 s
# 82.1 s
# 82.2 s
# 82.3 s
# 82.4 s
# 82.5 s
# 82.6 s
# 82.7 s
# 82.8 s
# 82.9 s
# 83.0 s
# 83.1 s
# 83.2 s
# 83.3 s
# 83.4 s
# 83.5 s
# 83.6 s
# 83.7 s
# 83.8 s
# 83.9 s
# 84.0 s
# 84.1 s
# 84.2 s
# 84.3 s
# 84.4 s
# 84.5 s
# 84.6 s
# 84.7 s
# 84.8 s
# 84.9 s
# 85.0 s
# 85.1 s
# 85.2 s
# 85.3 s
# 85.4 s
# 85.5 s
# 85.6 s
# 85.7 s
# 85.8 s
# 85.9 s
# 86.0 s
# 86.1 s
# 86.2 s
# 86.3 s
# 86.4 s
# 86.5 s
# 86.6 s
# 86.7 s
# 86.8 s
# 86.9 s
# 87.0 s
# 87.1 s
# 87.2 s
# 87.3 s
# 87.4 s
# 87.5 s
# 87.6 s
# 87.7 s
# 87.8 s
# 87.9 s
# 88.0 s
# 88.1 s
# 88.2 s
# 88.3 s
# 88.4 s
# 88.5 s
# 88.6 s
# 88.7 s
# 88.8 s
# 88.9 s
# 89.0 s
# 89.1 s
# 89.2 s
# 89.3 s
# 89.4 s
# 89.5 s
# 89.6 s
# 89.7 s
# 89.8 s
# 89.9 s
# 90.0 s
# 90.1 s
# 90.2 s
# 90.3 s
# 90.4 s
# 90.5 s
# 90.6 s
# 90.7 s
# 90.8 s
# 90.9 s
# 91.0 s
# 91.1 s
# 91.2 s
# 91.3 s
# 91.4 s
# 91.5 s
# 91.6 s
# 91.7 s
# 91.8 s
# 91.9 s
# 92.0 s
# 92.1 s
# 92.2 s
# 92.3 s
# 92.4 s
# 92.5 s
# 92.6 s
# 92.7 s
# 92.8 s
# 92.9 s
# 93.0 s
# 93.1 s
# 93.2 s
# 93.3 s
# 93.4 s
# 93.5 s
# 93.6 s
# 93.7 s
# 93.8 s
# 93.9 s
# 94.0 s
# 94.1 s
# 94.2 s
# 94.3 s
# 94.4 s
# 94.5 s
# 94.6 s
# 94.7 s
# 94.8 s
# 94.9 s
# 95.0 s
# 95.1 s
# 95.2 s
# 95.3 s
# 95.4 s
# 95.5 s
# 95.6 s
# 95.7 s
# 95.8 s
# 95.9 s
# 96.0 s
# 96.1 s
# 96.2 s
# 96.3 s
# 96.4 s
# 96.5 s
# 96.6 s
# 96.7 s
# 96.8 s
# 96.9 s
# 97.0 s
# 97.1 s
# 97.2 s
# 97.3 s
# 97.4 s
# 97.5 s
# 97.6 s
# 97.7 s
# 97.8 s
# 97.9 s
# 98.0 s
# 98.1 s
# 98.2 s
# 98.3 s
# 98.4 s
# 98.5 s
# 98.6 s
# 98.7 s
# 98.8 s
# 98.9 s
# 99.0 s
# 99.1 s
# 99.2 s
# 99.3 s
# 99.4 s
# 99.5 s
# 99.6 s
# 99.7 s
# 99.8 s
# 99.9 s
# 100.0 s
# 100.1 s
# 100.2 s
# 100.3 s
# 100.4 s
# 100.5 s
# 100.6 s
# 100.7 s
# 100.8 s
# 100.9 s
# 101.0 s
# 101.1 s
# 101.2 s
# 101.3 s
# 101.4 s
# 101.5 s
# 101.6 s
# 101.7 s
# 101.8 s
# 101.9 s
# 102.0 s
# 102.1 s
# 102.2 s
# 102.3 s
# 102.4 s
# 102.5 s
# 102.6 s
# 102.7 s
# 102.8 s
# 102.9 s
# 103.0 s
# 103.1 s
# 103.2 s
# 103.3 s
# 103.4 s
# 103.5 s
# 103.6 s
# 103.7 s
# 103.8 s
# 103.9 s
# 104.0 s
# 104.1 s
# 104.2 s
# 104.3 s
# 104.4 s
# 104.5 s
# 104.6 s
# 104.7 s
# 104.8 s
# 104.9 s
# 105.0 s
# 105.1 s
# 105.2 s
# 105.3 s
# 105.4 s
# 105.5 s
# 105.6 s
# 105.7 s
# 105.8 s
# 105.9 s
# 106.0 s
# 106.1 s
# 106.2 s
# 106.3 s
# 106.4 s
# 106.5 s
# 106.6 s
# 106.7 s
# 106.8 s
# 106.9 s
# 107.0 s
# 107.1 s
# 107.2 s
# 107.3 s
# 107.4 s
# 107.5 s
# 107.6 s
# 107.7 s
# 107.8 s
# 107.9 s
# 108.0 s
# 108.1 s
# 108.2 s
# 108.3 s
# 108.4 s
# 108.5 s
# 108.6 s
# 108.7 s
# 108.8 s
# 108.9 s
# 109.0 s
# 109.1 s
# 109.2 s
# 109.3 s
# 109.4 s
# 109.5 s
# 109.6 s
# 109.7 s
# 109.8 s
# 109.9 s
# 110.0 s
# 129.0 s
# 129.1 s
# 129.2 s
# 129.3 s
# 129.4 s
# 129.5 s
# 129.6 s
# 129.7 s
# 129.8 s
# 129.9 s
# 130.0 s
# 130.1 s
# 130.2 s
# 130.3 s
# 130.4 s
# 130.5 s
# 130.6 s
# 130.7 s
# 130.8 s
# 130.9 s
# 131.0 s
# 131.1 s
# 131.2 s
# 131.3 s
# 131.4 s
# 131.5 s
# 131.6 s
# 131.7 s
# 131.8 s
# 131.9 s
# 132.0 s
# 132.1 s
# 132.2 s
# 132.3 s
# 132.4 s
# 132.5 s
# 132.6 s
# 132.7 s
# 132.8 s
# 132.9 s
# 133.0 s
# 133.1 s
# 133.2 s
# 133.3 s
# 133.4 s
# 133.5 s
# 133.6 s
# 133.7 s
# 133.8 s
# 133.9 s
# 134.0 s
# 134.1 s
# 134.2 s
# 134.3 s
# 134.4 s
# 134.5 s
# 134.6 s
# 134.7 s
# 134.8 s
# 134.9 s
# 135.0 s
# 135.1 s
# 135.2 s
# 135.3 s
# 135.4 s
# 135.5 s
# 135.6 s
# 135.7 s
# 135.8 s
# 135.9 s
# 136.0 s
# 136.1 s
# 136.2 s
# 136.3 s
# 136.4 s
# 136.5 s
# 136.6 s
# 136.7 s
# 136.8 s
# 136.9 s
# 137.0 s
# 137.1 s
# 137.2 s
# 137.3 s
# 137.4 s
# 137.5 s
# 137.6 s
# 137.7 s
# 137.8 s
# 137.9 s
# 138.0 s
# 138.1 s
# 138.2 s
# 138.3 s
# 138.4 s
# 138.5 s
# 138.6 s
# 138.7 s
# 138.8 s
# 138.9 s
# 139.0 s
# 139.1 s
# 139.2 s
# 139.3 s
# 139.4 s
# 139.5 s
# 139.6 s
# 139.7 s
# 139.8 s
# 139.9 s
# 140.0 s
# 140.1 s
# 140.2 s
# 140.3 s
# 140.4 s
# 140.5 s
# 140.6 s
# 140.7 s
# 140.8 s
# 140.9 s
# 141.0 s
# 141.1 s
# 141.2 s
# 141.3 s
# 141.4 s
# 141.5 s
# 141.6 s
# 141.7 s
# 141.8 s
# 141.9 s
# 142.0 s
# 142.1 s
# 142.2 s
# 142.3 s
# 142.4 s
# 142.5 s
# 142.6 s
# 142.7 s
# 142.8 s
# 142.9 s
# 143.0 s
# 143.1 s
# 143.2 s
# 143.3 s
# 143.4 s
# 143.5 s
# 143.6 s
# 143.7 s
# 143.8 s
# 143.9 s
# 144.0 s
# 144.1 s
# 144.2 s
# 144.3 s
# 144.4 s
# 144.5 s
# 144.6 s
# 144.7 s
# 144.8 s
# 144.9 s
# 145.0 s
# 145.1 s
# 145.2 s
# 145.3 s
# 145.4 s
# 145.5 s
# 145.6 s
# 145.7 s
# 145.8 s
# 145.9 s
# 146.0 s
# 146.1 s
# 146.2 s
# 146.3 s
# 146.4 s
# 146.5 s
# 146.6 s
# 146.7 s
# 146.8 s
# 146.9 s
# 147.0 s
# 147.1 s
# 147.2 s
# 147.3 s
# 147.4 s
# 147.5 s
# 147.6 s
# 147.7 s
# 147.8 s
# 280.2 s
# 280.3 s
# 280.4 s
# 280.5 s
# 280.6 s
# 280.7 s
# 280.8 s
# 280.9 s
# 281.0 s
# 281.1 s
# 281.2 s
# 281.3 s
# 281.4 s
# 281.5 s
# 281.6 s
# 281.7 s
# 281.8 s
# 281.9 s

# %%
rf_data_median.shape
# Out:
# (2810, 9, 8)

# %%
pf_data_median.shape
# Out:
# (2810, 94, 8)

# %%
plt.figure(figsize=(15,5))
plt.imshow(pf_data_median[:,:,4].T, aspect='auto', cmap='seismic'); plt.colorbar(); plt.clim(-2,2)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.imshow(rf_data_median[:,:,4].T, aspect='auto', cmap='seismic'); plt.colorbar(); plt.clim(-2,2)
plt.show()

# %%
mov_con = dat_MOV[1,:][::100][10:]
mov_ips = dat_MOV[0,:][::100][10:]

# %%
np.save('rf_data_median.npy', rf_data_median)
np.save('pf_data_median.npy', pf_data_median)
np.save('dat_con.npy', mov_con)
np.save('dat_ips.npy', mov_ips)

# %%
rf_data_median = np.load('rf_data_median.npy')
pf_data_median = np.load('pf_data_median.npy')
mov_con = np.load('dat_con.npy')
mov_ips = np.load('dat_ips.npy')

# %% [markdown]
# ### Training a classifier

# %%
def append_time_dim(X, y_=None, time_stamps=5):
    """
    :param X: in shape(time, grid_points/channels, f_bands)
    apply added time dimension for the data array and label given time_stamps (with downsample_rate=100) in 100ms / need to check with 1375Hz
    """
    if len(X.shape) == 3:
        num_time = X.shape[0]
        num_channels = X.shape[1]
        num_f_bands = X.shape[2]

        time_arr = np.zeros([num_time-time_stamps, num_channels, int(time_stamps*num_f_bands)])
        for ch in range(num_channels):
            for time_idx, time_ in enumerate(np.arange(time_stamps, num_time)):
                for time_point in range(time_stamps):
                    time_arr[time_idx, ch, time_point*num_f_bands:(time_point+1)*num_f_bands] = X[time_-time_point,ch,:]

        if y_ is None:
            return time_arr
        return time_arr, y_[time_stamps:]
    elif len(X.shape) == 2:
        if time_stamps == X.shape[0]:
            time_arr = np.zeros([1+X.shape[0]-time_stamps, int(time_stamps*X.shape[1])])
            #print(time_arr.shape)
            for time_idx, time_ in enumerate(np.arange(time_stamps-1, X.shape[0])):
                #print(time_idx)
                #print('time_:'+str(time_))
                for time_point in range(time_stamps):
                    #print('time_point: '+str(time_point))
                    time_arr[time_idx, time_point*X.shape[1]:(time_point+1)*X.shape[1]] = X[time_-time_point,:]
        else:
            time_arr = np.zeros([X.shape[0]-time_stamps, int(time_stamps*X.shape[1])])
            for time_idx, time_ in enumerate(np.arange(time_stamps, X.shape[0])):
                for time_point in range(time_stamps):
                    time_arr[time_idx, time_point*X.shape[1]:(time_point+1)*X.shape[1]] = X[time_-time_point,:]
        if y_ is None:
            return time_arr
        return time_arr, y_[time_stamps:]

# %%
pf_data_median.shape
# Out:
# (2810, 94, 8)

# %%
X = np.clip(pf_data_median, -2, 2)

# %%
X.shape
# Out:
# (2810, 94, 8)

# %%
grid_classifiers = np.empty(94, dtype=object)

# %%
for grid_point in range(arr_act_grid_points.shape[0]):
    if arr_act_grid_points[grid_point] == 0:
        continue
    if grid_point < 39:
        mov = mov_con
    elif grid_point >=39 and grid_point < 78:
        mov = mov_ips
    elif grid_point >=78 and grid_point < 85:
        mov = mov_con
    else: 
        mov = mov_ips
    X_, y_ = append_time_dim(X[:,grid_point,:], mov, 5)
    
    model = RandomForestRegressor(n_estimators=32, max_depth=4)
    #model = linear_model.LinearRegression()
    model.fit(X_, y_)
    print(grid_point)
    print(r2_score(y_, model.predict(X_)))
    grid_classifiers[grid_point] = model
# Out:
# 1
# 0.9145101195939698
# 2
# 0.9142034414203107
# 5
# 0.9331290657530004
# 7
# 0.9411742522728473
# 10
# 0.9276800420908718
# 11
# 0.9318985918562246
# 13
# 0.9356759622498031
# 16
# 0.91224361436611
# 19
# 0.8731371617673096
# 20
# 0.8320657362840115
# 21
# 0.7428949372835345
# 23
# 0.7992202500034826
# 24
# 0.7889324376352878
# 27
# 0.7798871661913157
# 28
# 0.7375616715605778
# 32
# 0.7352568271325275
# 40
# 0.6913075911851958
# 41
# 0.6895258915971114
# 44
# 0.7993699980910238
# 46
# 0.7936463956976535
# 49
# 0.7670053849954731
# 50
# 0.7523626458606122
# 52
# 0.75212102736472
# 55
# 0.6572263156893697
# 58
# 0.6294165748303941
# 59
# 0.5608411535708022
# 60
# 0.5350048848628552
# 62
# 0.552132069203531
# 63
# 0.5478635934061376
# 66
# 0.551910960277354
# 67
# 0.5386269420943703
# 71
# 0.533883647043857
# 78
# 0.6926420512297901
# 79
# 0.7079101331862125
# 80
# 0.6755646869846497
# 81
# 0.7205964732920269
# 82
# 0.7096081764702322
# 83
# 0.6622097439225688
# 86
# 0.37427049289717695
# 87
# 0.35379414040948853
# 88
# 0.30725641526602243
# 89
# 0.34299666986888955
# 90
# 0.35580338247603205
# 91
# 0.389168422823153

# %%
np.save('grid_classifiers.npy', grid_classifiers)

# %%
grid_classifiers = np.load('grid_classifiers.npy', allow_pickle=True)

# %% [markdown]
# ### Real Time implementation

# %%
vhdr_file = files[3]

# %%
bv_raw, ch_names = M1_tf_interpolation_BIDS.read_BIDS_file(vhdr_file)
# Out:
# Extracting parameters from /Users/hi/Documents/lab_work/BIDS/sub-000/ses-right/eeg/sub-000_ses-right_task-force_run-3_eeg.vhdr...
# Setting channel info structure...

# %%
bv_raw.shape
# Out:
# (11, 282000)

# %%
def simulate_data_stream(bv_raw, ind_DAT, ind_time, fs):
    #time.sleep(1/fs)
    return bv_raw[ind_DAT, ind_time]

# %%
def predict(pf_stream, grid_classifiers):
    res_predict = np.zeros([94])
    X = np.clip(pf_stream, -2, 2)
    for grid_point in range(arr_act_grid_points.shape[0]):
        if arr_act_grid_points[grid_point] == 0:
            continue
        X_test = append_time_dim(X[:,grid_point,:], time_stamps=5)
        model = grid_classifiers[grid_point]
        res_predict[grid_point] = model.predict(X_test)
    return res_predict

# %%
normalization_time
# Out:
# 10

# %%
fs_new
# Out:
# 10

# %%
fs
# Out:
# 1000.0

# %%
normalization_samples = normalization_time*fs_new

# %%
normalization_samples
# Out:
# 100

# %%
bv_raw.shape[1]
# Out:
# 282000

# %%
normalization_samples
# Out:
# 100

# %%
plt.rcParams.update({'font.size': 22})

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
plt.ion()
plt.title('movement predictions grid point 42')
fig.show()
fig.canvas.draw()

dat_buffer = np.zeros([ind_DAT.shape[0], 1000])
dat_res = np.zeros([94, 100])
dat_label_con = np.zeros([100])
dat_label_ips = np.zeros([100])
rf_data_rt = np.zeros([ind_DAT.shape[0], 8])
pf_data_rt = np.zeros([94, 8])

pf_stream = []
rf_stream = []
pf_stream_median = []
rf_stream_median = []
estimates = []
buffer_counter = 0
idx_stream = 0
for ind_time in range(bv_raw.shape[1]):
    if idx_stream == 0:
        if buffer_counter < seglengths[0]-1:
            dat_buffer[:, buffer_counter] = simulate_data_stream(bv_raw, ind_DAT, ind_time, fs)
            buffer_counter += 1 
            continue
    else:
        if buffer_counter < seglengths[7]-1:
            dat_buffer[:,:-1] = dat_buffer[:,1:]
            buffer_offset = seglengths[0] - seglengths[-1] # to have steps of 100 ms
            dat_buffer[:, buffer_counter+buffer_offset] = simulate_data_stream(bv_raw, ind_DAT, ind_time, fs)
            buffer_counter += 1 
            continue
    #plt.imshow(dat_buffer, aspect='auto')
    #plt.title('buffer')
    #plt.show()
    #print(ind_time)
    #print(str(np.round(ind_time*(1/fs),2))+' s')
    buffer_counter = 0    
    
    rf_data_rt = np.zeros([ind_DAT.shape[0], 8])
    pf_data_rt = np.zeros([94, 8])
    for ch in ind_DAT:  #  think about using multiprocessing pool to do this simulatenously
        dat_ = dat_buffer[ch,:]
        dat_filt = M1_tf_interpolation_BIDS.apply_filter(dat_, sample_rate=fs, filter_fun=filter_fun, line_noise=line_noise, seglengths=seglengths)
        rf_data_rt[ch,:] = dat_filt
    
    #plt.imshow(rf_data_rt.T, aspect='auto')
    #plt.title('raw t-f transformed')
    #plt.show()
    
    #PROJECTION of RF_data to pf_data
    dat_ECOG = rf_data_rt[ind_ECOG,:]
    dat_STN = rf_data_rt[ind_STN,:]
    proj_ECOG, proj_STN = M1_tf_interpolation_BIDS.get_projected_ECOG_STN_data(proj_matrix_run, sess_right, dat_ECOG, dat_STN)
    pf_data_rt = M1_tf_interpolation_BIDS.write_proj_data(ch_names, sess_right, dat_MOV, ind_MOV, proj_ECOG, proj_STN)
    
    #plt.imshow(pf_data_rt.T, aspect='auto')
    #plt.title('projected t-f transformed')
    #plt.show()
    
    if idx_stream<normalization_samples:
        if idx_stream == 0:
            n_idx = 0
        else:
            n_idx = np.arange(0,idx_stream,1)
    else:
        n_idx = np.arange(idx_stream-normalization_samples, idx_stream, 1)
    
    if idx_stream == 0:

        pf_stream.append(pf_data_rt)
        pf_stream_median.append(pf_data_rt)
        
        rf_stream.append(rf_data_rt)
        rf_stream_median.append(rf_data_rt)
    else:
        
        rf_stream.append(rf_data_rt)
        median_ = np.median(np.array(rf_stream)[n_idx,:,:], axis=0)
        rf_stream_val = (rf_data_rt - median_) / median_
        rf_stream_median.append(rf_stream_val)
        
        pf_stream.append(pf_data_rt)
        median_ = np.median(np.array(pf_stream)[n_idx,:,:][:,arr_act_grid_points>0,:], axis=0)
        pf_data_rt_median = (pf_data_rt[arr_act_grid_points>0,:] - median_) / median_
        pf_data_set = np.zeros([94, 8])
        pf_data_set[arr_act_grid_points>0,:] = pf_data_rt_median
        pf_stream_median.append(pf_data_set)
        
        #plt.imshow(pf_data_rt.T, aspect='auto')
        #plt.title('projected and resampled t-f transformed')
        #plt.show()
        
        # now use the predictors to estimate the movement 
        if idx_stream >= 5:
            time_stamp_tf_dat = np.array(pf_stream_median)[-5:,:,:]
            #plt.imshow(time_stamp_tf_dat[:,:,0].T, aspect='auto')
            #plt.clim(-10,10)
            #plt.show()
            predictions = predict(time_stamp_tf_dat, grid_classifiers)
            estimates.append(predictions)
            
            dat_res[:,:-1] = dat_res[:,1:]
            dat_res[:,-1] = predictions
            
            dat_label_con[:-1] = dat_label_con[1:]
            dat_label_con[-1] = mov_con[idx_stream-5]
            
            dat_label_ips[:-1] = dat_label_ips[1:]
            dat_label_ips[-1] = mov_ips[idx_stream-5]
            
            ax.clear()
            ax.plot(dat_res[46,:], label='prediction', c='green')
            ax.plot(dat_label_con, label='contralateral force', c='red')
            ax.plot(dat_label_ips, label='ipsilateral force', c='blue')
            ax.legend(loc='upper left')
            ax.set_ylabel('Force')
            ax.set_xlabel('Time 0.1s')
            ax.set_ylim(-1, 6)
            fig.canvas.draw()
            
    idx_stream += 1
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-303-414ce69f365c> in <module>
#      84
#      85         pf_stream.append(pf_data_rt)
# ---> 86         median_ = np.median(np.array(pf_stream)[n_idx,:,:][:,arr_act_grid_points>0,:], axis=0)
#      87         pf_data_rt_median = (pf_data_rt[arr_act_grid_points>0,:] - median_) / median_
#      88         pf_data_set = np.zeros([94, 8])
#
# KeyboardInterrupt:

# %%
np.array(estimates).shape
# Out:
# (883, 94)

# %%
plt.figure(figsize=(15,5))
plt.imshow(np.array(pf_stream_median)[:,:,4].T, aspect='auto', cmap='seismic'); plt.colorbar(); 
plt.plot(mov_con[:np.array(estimates).shape[0]]+20, label='con', color='black')
plt.plot(mov_ips[:np.array(estimates).shape[0]]+30, label='ips', color='green')
plt.clim(-2,2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.imshow(np.array(rf_stream_median)[:,:,4].T, aspect='auto', cmap='seismic'); plt.colorbar(); 
plt.plot(mov_con[:np.array(estimates).shape[0]]+10, label='con', color='black')
plt.plot(mov_ips[:np.array(estimates).shape[0]]+15, label='ips', color='green')
plt.clim(-2,2)
plt.legend()
plt.show()

# %%
# %matplotlib inline
#%matplotlib notebook

# %%
for idx_, grid_point in enumerate(np.nonzero(arr_act_grid_points)[0]):
    plt.title(grid_point)
    plt.plot(np.array(estimates)[:,grid_point])
    plt.plot(mov_con[5:np.array(estimates)[:,grid_point].shape[0]], label='con')
    plt.plot(mov_ips[5:np.array(estimates)[:,grid_point].shape[0]], label='ips')
    plt.legend()
    plt.show()
