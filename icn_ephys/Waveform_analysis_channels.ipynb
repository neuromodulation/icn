# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sn
import scipy
import mne
import os
import pandas as pd
import numpy as np
import mne
import scipy
import pickle

# %%
PATH_TROUGHS = "../../../../Dropbox (Brain Modulation Lab)/Shared Lab Folders/CRCNS/MOVEMENT DATA/SharpWaveAnalysis/"
PATH_PEAKS = "../../../../Dropbox (Brain Modulation Lab)/Shared Lab Folders/CRCNS/MOVEMENT DATA/SharpWaveAnalysis_Peaks/"
PATH_COMBINED = "../../../../Dropbox (Brain Modulation Lab)/Shared Lab Folders/CRCNS/MOVEMENT DATA/Combined_runs/"
PATH_SAVE = "../../../../Dropbox (Brain Modulation Lab)/Shared Lab Folders/CRCNS/MOVEMENT DATA/SharpWaveAnalysis/preprocessed/"
subjects = ['000', '001', '004', '005', '006', '007', '008', '009', '010', '013', '014']

# %%
dict_metrics_TROUGH = {"sharpness":"mV", 
                "trough":"mV",
                "interval":"ms",
                "prominence":"mV",
                "rise_steepness":"mV'",
                "rise_time":"ms", 
                "decay_steepness":"mV'",
                "slope_ratio":"mV'",
                "decay_time":"ms",
                "width":"ms"}

dict_metrics_PEAK = {"sharpness":"mV", 
                "peak":"mV",
                "interval":"ms",
                "prominence":"mV",
                "rise_steepness":"mV'",
                "rise_time":"ms", 
                "decay_steepness":"mV'",
                "slope_ratio":"mV'",
                "decay_time":"ms",
                "width":"ms"}


def plot_mov_sep_hist(metric, label):
    sn.distplot(df[df.MOV_TYPE.str.contains("NONE")][metric], label='None', color='black')
    sn.distplot(df[df.MOV_TYPE.str.contains("CON")][metric], label='CON', color='red')
    sn.distplot(df[df.MOV_TYPE.str.contains("IPS")][metric], label='IPS', color='blue')
    plt.title(metric)
    plt.xlabel(metric + " [" + label+"]")
    plt.legend()
    
def plot_hist_comp(metric, metric_unit, df):
    p = np.array(df[df.MOV_TYPE.str.contains("NO_MOV")][metric])
    q_con = np.array(df[df.MOV_TYPE.str.contains("CON")][metric])
    q_ips = np.array(df[df.MOV_TYPE.str.contains("IPS")][metric])

    range_ = [np.min(np.concatenate([q_con, q_ips, p])), np.max(np.concatenate([q_con, q_ips, p]))]
    p_, x, _ = plt.hist(p, density=True, bins=50, range=range_, alpha=0.3, color="black")
    q_con_ = plt.hist(q_con, density=True, bins=50, range=range_, alpha=0.3, color="r")[0]
    # for Dkl replace zero elements with e-9
    Dkl_con = np.round(scipy.stats.entropy(np.where(p_ == 0.0, 1e-9, p_), np.where(q_con_ == 0.0, 1e-9, q_con_)), 2)
    
    # adapt this measure 
    
    q_ips_ = plt.hist(q_ips, density=True, bins=50, range=range_, alpha=0.3, color="b")[0]
    Dkl_ips = np.round(scipy.stats.entropy(np.where(p_ == 0.0, 1e-9, p_), np.where(q_ips_ == 0.0, 1e-9, q_ips_)), 2)


    density_p = scipy.stats.gaussian_kde(p)
    density_q_con = scipy.stats.gaussian_kde(q_con)
    density_q_ips = scipy.stats.gaussian_kde(q_ips)
    plt.plot(x, density_p(x), c="black", label='NO_MOV')
    plt.plot(x, density_q_con(x), c="r", label='CON')
    plt.plot(x, density_q_ips(x), c="b", label='IPS')
    plt.legend()

    plt.title("Dkl_con = " + str(Dkl_con)+ "\nDkl_ips = "+ str(Dkl_ips))
    plt.xlabel(metric + " ["+ metric_unit+"]")
    return Dkl_con, Dkl_ips

def get_sharpness_ratio(df_PEAKS, df_TROUGHS, MOV_TYPE):
    df_PEAKS_ = df_PEAKS[df_PEAKS.MOV_TYPE == MOV_TYPE]
    df_TROUGHS_ = df_TROUGHS[df_TROUGHS.MOV_TYPE == MOV_TYPE]
    
    sharpness_tr = np.sum(df_TROUGHS_["sharpness"]) / df_TROUGHS_["sharpness"].shape[0]
    sharpness_pe = np.sum(df_PEAKS_["sharpness"]) / df_PEAKS_["sharpness"].shape[0]
    sharpness_ratio = np.max([sharpness_pe/sharpness_tr, sharpness_tr/sharpness_pe])
    
    return sharpness_ratio

# %%
files_TROUGHS = os.listdir(PATH_TROUGHS)
files_PEAKS = os.listdir(PATH_PEAKS)
df = np.load(os.path.join(PATH_, files_[0]), allow_pickle=True)

# %%
files_PEAKS
# Out:
# ['sub_005_ch_ECOG_LEFT_3.p',
#  'sub_002_ch_ECOG_RIGHT_0.p',
#  'sub_010_ch_ECOG_LEFT_4.p',
#  'sub_004_ch_STN_LEFT_1.p',
#  'sub_006_ch_ECOG_RIGHT_21.p',
#  'sub_005_ch_ECOG_RIGHT_7.p',
#  'sub_004_ch_ECOG_LEFT_0.p',
#  'sub_006_ch_ECOG_LEFT_21.p',
#  'sub_013_ch_ECOG_LEFT_1.p',
#  'sub_006_ch_ECOG_LEFT_6.p',
#  'sub_000_ch_ECOG_RIGHT_3.p',
#  'sub_001_ch_ECOG_RIGHT_27.p',
#  'sub_010_ch_STN_RIGHT_1.p',
#  'sub_006_ch_STN_LEFT_0.p',
#  'sub_007_ch_ECOG_LEFT_5.p',
#  'sub_001_ch_ECOG_LEFT_26.p',
#  'sub_012_ch_ECOG_LEFT_2.p',
#  'sub_006_ch_ECOG_LEFT_8.p',
#  'sub_005_ch_STN_RIGHT_2.p',
#  'sub_001_ch_ECOG_LEFT_22.p',
#  'sub_007_ch_ECOG_LEFT_1.p',
#  'sub_006_ch_ECOG_LEFT_2.p',
#  'sub_014_ch_ECOG_RIGHT_2.p',
#  'sub_006_ch_ECOG_LEFT_25.p',
#  'sub_013_ch_ECOG_LEFT_5.p',
#  'sub_009_ch_STN_LEFT_0.p',
#  'sub_001_ch_ECOG_RIGHT_23.p',
#  'sub_004_ch_STN_RIGHT_1.p',
#  'sub_010_ch_STN_LEFT_0.p',
#  'sub_006_ch_ECOG_RIGHT_25.p',
#  'sub_004_ch_ECOG_LEFT_4.p',
#  'sub_005_ch_ECOG_RIGHT_3.p',
#  'sub_011_ch_ECOG_LEFT_3.p',
#  'sub_010_ch_ECOG_LEFT_0.p',
#  'sub_002_ch_ECOG_RIGHT_4.p',
#  'sub_005_ch_ECOG_LEFT_7.p',
#  'sub_015_ch_ECOG_LEFT_3.p',
#  'sub_003_ch_ECOG_RIGHT_0.p',
#  'sub_008_ch_ECOG_LEFT_5.p',
#  'sub_006_ch_ECOG_RIGHT_10.p',
#  'sub_015_ch_ECOG_LEFT_9.p',
#  'sub_006_ch_ECOG_LEFT_35.p',
#  'sub_001_ch_ECOG_LEFT_7.p',
#  'sub_004_ch_ECOG_RIGHT_7.p',
#  'sub_010_ch_ECOG_RIGHT_2.p',
#  'sub_003_ch_ECOG_LEFT_1.p',
#  'sub_006_ch_ECOG_RIGHT_35.p',
#  'sub_001_ch_ECOG_RIGHT_3.p',
#  'sub_001_ch_ECOG_LEFT_17.p',
#  'sub_001_ch_STN_RIGHT_2.p',
#  'sub_001_ch_ECOG_RIGHT_9.p',
#  'sub_001_ch_ECOG_RIGHT_16.p',
#  'sub_000_ch_STN_RIGHT_1.p',
#  'sub_006_ch_ECOG_LEFT_10.p',
#  'sub_005_ch_STN_LEFT_2.p',
#  'sub_006_ch_ECOG_RIGHT_4.p',
#  'sub_012_ch_ECOG_RIGHT_1.p',
#  'sub_001_ch_ECOG_RIGHT_12.p',
#  'sub_001_ch_ECOG_LEFT_19.p',
#  'sub_001_ch_STN_LEFT_0.p',
#  'sub_012_ch_ECOG_RIGHT_5.p',
#  'sub_006_ch_ECOG_LEFT_14.p',
#  'sub_006_ch_ECOG_RIGHT_0.p',
#  'sub_006_ch_ECOG_RIGHT_31.p',
#  'sub_001_ch_ECOG_RIGHT_7.p',
#  'sub_001_ch_ECOG_LEFT_13.p',
#  'sub_003_ch_ECOG_LEFT_5.p',
#  'sub_001_ch_ECOG_RIGHT_18.p',
#  'sub_014_ch_STN_RIGHT_1.p',
#  'sub_006_ch_ECOG_LEFT_31.p',
#  'sub_003_ch_STN_RIGHT_0.p',
#  'sub_001_ch_ECOG_LEFT_3.p',
#  'sub_013_ch_STN_LEFT_2.p',
#  'sub_004_ch_ECOG_RIGHT_3.p',
#  'sub_009_ch_ECOG_LEFT_2.p',
#  'sub_003_ch_ECOG_RIGHT_4.p',
#  'sub_003_ch_STN_LEFT_1.p',
#  'sub_008_ch_ECOG_LEFT_1.p',
#  'sub_015_ch_ECOG_LEFT_7.p',
#  'sub_001_ch_ECOG_LEFT_9.p',
#  'sub_006_ch_ECOG_RIGHT_14.p',
#  'sub_000_ch_ECOG_RIGHT_0.p',
#  'sub_006_ch_ECOG_LEFT_5.p',
#  'sub_013_ch_ECOG_LEFT_2.p',
#  'sub_006_ch_ECOG_LEFT_22.p',
#  'sub_014_ch_ECOG_RIGHT_5.p',
#  'sub_001_ch_ECOG_RIGHT_24.p',
#  'sub_006_ch_ECOG_LEFT_28.p',
#  'sub_010_ch_STN_RIGHT_2.p',
#  'sub_012_ch_ECOG_LEFT_1.p',
#  'sub_001_ch_ECOG_LEFT_25.p',
#  'sub_006_ch_ECOG_RIGHT_28.p',
#  'sub_002_ch_ECOG_RIGHT_3.p',
#  'sub_005_ch_ECOG_LEFT_0.p',
#  'sub_004_ch_STN_LEFT_2.p',
#  'sub_006_ch_STN_RIGHT_0.p',
#  'sub_006_ch_ECOG_RIGHT_22.p',
#  'sub_004_ch_ECOG_LEFT_3.p',
#  'sub_011_ch_ECOG_LEFT_4.p',
#  'sub_005_ch_ECOG_RIGHT_4.p',
#  'sub_006_ch_ECOG_RIGHT_26.p',
#  'sub_011_ch_ECOG_LEFT_0.p',
#  'sub_005_ch_ECOG_RIGHT_0.p',
#  'sub_004_ch_ECOG_LEFT_7.p',
#  'sub_005_ch_ECOG_LEFT_4.p',
#  'sub_002_ch_ECOG_RIGHT_7.p',
#  'sub_010_ch_ECOG_LEFT_3.p',
#  'sub_005_ch_STN_RIGHT_1.p',
#  'sub_007_ch_ECOG_LEFT_2.p',
#  'sub_012_ch_ECOG_LEFT_5.p',
#  'sub_001_ch_ECOG_LEFT_21.p',
#  'sub_006_ch_ECOG_LEFT_26.p',
#  'sub_014_ch_ECOG_RIGHT_1.p',
#  'sub_000_ch_ECOG_RIGHT_4.p',
#  'sub_006_ch_ECOG_LEFT_1.p',
#  'sub_004_ch_STN_RIGHT_2.p',
#  'sub_001_ch_ECOG_RIGHT_20.p',
#  'sub_001_ch_ECOG_LEFT_14.p',
#  'sub_001_ch_ECOG_RIGHT_0.p',
#  'sub_003_ch_ECOG_LEFT_2.p',
#  'sub_015_ch_ECOG_LEFT_11.p',
#  'sub_006_ch_ECOG_LEFT_19.p',
#  'sub_001_ch_STN_RIGHT_1.p',
#  'sub_012_ch_ECOG_RIGHT_8.p',
#  'sub_000_ch_STN_RIGHT_2.p',
#  'sub_001_ch_ECOG_RIGHT_15.p',
#  'sub_012_ch_ECOG_RIGHT_2.p',
#  'sub_006_ch_ECOG_RIGHT_7.p',
#  'sub_005_ch_STN_LEFT_1.p',
#  'sub_006_ch_ECOG_LEFT_13.p',
#  'sub_003_ch_ECOG_RIGHT_3.p',
#  'sub_015_ch_ECOG_LEFT_0.p',
#  'sub_007_ch_STN_LEFT_0.p',
#  'sub_006_ch_ECOG_RIGHT_13.p',
#  'sub_010_ch_ECOG_RIGHT_1.p',
#  'sub_006_ch_ECOG_RIGHT_19.p',
#  'sub_009_ch_ECOG_LEFT_5.p',
#  'sub_004_ch_ECOG_RIGHT_4.p',
#  'sub_001_ch_ECOG_LEFT_4.p',
#  'sub_006_ch_ECOG_LEFT_32.p',
#  'sub_008_ch_STN_LEFT_0.p',
#  'sub_009_ch_ECOG_LEFT_1.p',
#  'sub_004_ch_ECOG_RIGHT_0.p',
#  'sub_001_ch_ECOG_LEFT_0.p',
#  'sub_013_ch_STN_LEFT_1.p',
#  'sub_010_ch_ECOG_RIGHT_5.p',
#  'sub_015_ch_ECOG_LEFT_4.p',
#  'sub_008_ch_ECOG_LEFT_2.p',
#  'sub_003_ch_STN_LEFT_2.p',
#  'sub_003_ch_ECOG_RIGHT_7.p',
#  'sub_006_ch_ECOG_RIGHT_17.p',
#  'sub_001_ch_ECOG_RIGHT_11.p',
#  'sub_006_ch_ECOG_RIGHT_3.p',
#  'sub_006_ch_ECOG_LEFT_17.p',
#  'sub_012_ch_ECOG_RIGHT_6.p',
#  'sub_003_ch_ECOG_LEFT_6.p',
#  'sub_001_ch_ECOG_LEFT_10.p',
#  'sub_001_ch_ECOG_RIGHT_4.p',
#  'sub_006_ch_ECOG_RIGHT_32.p',
#  'sub_006_ch_ECOG_RIGHT_9.p',
#  'sub_014_ch_STN_RIGHT_2.p',
#  'sub_012_ch_ECOG_LEFT_0.p',
#  'sub_001_ch_ECOG_LEFT_24.p',
#  'sub_006_ch_STN_LEFT_2.p',
#  'sub_006_ch_ECOG_LEFT_29.p',
#  'sub_001_ch_ECOG_RIGHT_25.p',
#  'sub_013_ch_ECOG_LEFT_3.p',
#  'sub_006_ch_ECOG_LEFT_23.p',
#  'sub_014_ch_ECOG_RIGHT_4.p',
#  'sub_000_ch_ECOG_RIGHT_1.p',
#  'sub_006_ch_ECOG_LEFT_4.p',
#  'sub_011_ch_ECOG_LEFT_5.p',
#  'sub_005_ch_ECOG_RIGHT_5.p',
#  'sub_004_ch_ECOG_LEFT_2.p',
#  'sub_006_ch_ECOG_RIGHT_23.p',
#  'sub_006_ch_STN_RIGHT_1.p',
#  'sub_005_ch_ECOG_LEFT_1.p',
#  'sub_002_ch_ECOG_RIGHT_2.p',
#  'sub_006_ch_ECOG_RIGHT_29.p',
#  'sub_010_ch_ECOG_LEFT_2.p',
#  'sub_002_ch_ECOG_RIGHT_6.p',
#  'sub_005_ch_ECOG_LEFT_5.p',
#  'sub_004_ch_ECOG_LEFT_6.p',
#  'sub_011_ch_ECOG_LEFT_1.p',
#  'sub_005_ch_ECOG_RIGHT_1.p',
#  'sub_010_ch_STN_LEFT_2.p',
#  'sub_006_ch_ECOG_RIGHT_27.p',
#  'sub_009_ch_STN_LEFT_2.p',
#  'sub_001_ch_ECOG_RIGHT_21.p',
#  'sub_000_ch_ECOG_RIGHT_5.p',
#  'sub_006_ch_ECOG_LEFT_0.p',
#  'sub_006_ch_ECOG_LEFT_27.p',
#  'sub_014_ch_ECOG_RIGHT_0.p',
#  'sub_012_ch_ECOG_LEFT_4.p',
#  'sub_001_ch_ECOG_LEFT_20.p',
#  'sub_007_ch_ECOG_LEFT_3.p',
#  'sub_005_ch_STN_RIGHT_0.p',
#  'sub_006_ch_ECOG_RIGHT_6.p',
#  'sub_005_ch_STN_LEFT_0.p',
#  'sub_006_ch_ECOG_LEFT_12.p',
#  'sub_012_ch_ECOG_RIGHT_3.p',
#  'sub_001_ch_ECOG_RIGHT_14.p',
#  'sub_012_ch_ECOG_RIGHT_9.p',
#  'sub_001_ch_STN_RIGHT_0.p',
#  'sub_006_ch_ECOG_LEFT_18.p',
#  'sub_015_ch_ECOG_LEFT_10.p',
#  'sub_003_ch_ECOG_LEFT_3.p',
#  'sub_001_ch_ECOG_LEFT_15.p',
#  'sub_001_ch_ECOG_RIGHT_1.p',
#  'sub_004_ch_ECOG_RIGHT_5.p',
#  'sub_009_ch_ECOG_LEFT_4.p',
#  'sub_001_ch_ECOG_LEFT_5.p',
#  'sub_006_ch_ECOG_RIGHT_18.p',
#  'sub_010_ch_ECOG_RIGHT_0.p',
#  'sub_006_ch_ECOG_RIGHT_12.p',
#  'sub_015_ch_ECOG_LEFT_1.p',
#  'sub_007_ch_STN_LEFT_1.p',
#  'sub_003_ch_ECOG_RIGHT_2.p',
#  'sub_006_ch_ECOG_RIGHT_16.p',
#  'sub_008_ch_ECOG_LEFT_3.p',
#  'sub_003_ch_ECOG_RIGHT_6.p',
#  'sub_015_ch_ECOG_LEFT_5.p',
#  'sub_010_ch_ECOG_RIGHT_4.p',
#  'sub_004_ch_ECOG_RIGHT_1.p',
#  'sub_009_ch_ECOG_LEFT_0.p',
#  'sub_008_ch_STN_LEFT_1.p',
#  'sub_001_ch_ECOG_LEFT_1.p',
#  'sub_013_ch_STN_LEFT_0.p',
#  'sub_006_ch_ECOG_LEFT_33.p',
#  'sub_003_ch_STN_RIGHT_2.p',
#  'sub_006_ch_ECOG_RIGHT_8.p',
#  'sub_001_ch_ECOG_LEFT_11.p',
#  'sub_001_ch_ECOG_RIGHT_5.p',
#  'sub_006_ch_ECOG_RIGHT_33.p',
#  'sub_003_ch_ECOG_LEFT_7.p',
#  'sub_001_ch_STN_LEFT_2.p',
#  'sub_012_ch_ECOG_RIGHT_7.p',
#  'sub_006_ch_ECOG_RIGHT_2.p',
#  'sub_006_ch_ECOG_LEFT_16.p',
#  'sub_001_ch_ECOG_RIGHT_10.p',
#  'sub_004_ch_ECOG_LEFT_1.p',
#  'sub_005_ch_ECOG_RIGHT_6.p',
#  'sub_006_ch_STN_RIGHT_2.p',
#  'sub_006_ch_ECOG_RIGHT_20.p',
#  'sub_004_ch_STN_LEFT_0.p',
#  'sub_010_ch_ECOG_LEFT_5.p',
#  'sub_002_ch_ECOG_RIGHT_1.p',
#  'sub_005_ch_ECOG_LEFT_2.p',
#  'sub_001_ch_ECOG_LEFT_27.p',
#  'sub_012_ch_ECOG_LEFT_3.p',
#  'sub_007_ch_ECOG_LEFT_4.p',
#  'sub_010_ch_STN_RIGHT_0.p',
#  'sub_006_ch_STN_LEFT_1.p',
#  'sub_001_ch_ECOG_RIGHT_26.p',
#  'sub_006_ch_ECOG_LEFT_7.p',
#  'sub_000_ch_ECOG_RIGHT_2.p',
#  'sub_006_ch_ECOG_LEFT_20.p',
#  'sub_013_ch_ECOG_LEFT_0.p',
#  'sub_004_ch_STN_RIGHT_0.p',
#  'sub_009_ch_STN_LEFT_1.p',
#  'sub_001_ch_ECOG_RIGHT_22.p',
#  'sub_014_ch_ECOG_RIGHT_3.p',
#  'sub_006_ch_ECOG_LEFT_24.p',
#  'sub_013_ch_ECOG_LEFT_4.p',
#  'sub_006_ch_ECOG_LEFT_3.p',
#  'sub_007_ch_ECOG_LEFT_0.p',
#  'sub_001_ch_ECOG_LEFT_23.p',
#  'sub_006_ch_ECOG_LEFT_9.p',
#  'sub_005_ch_ECOG_LEFT_6.p',
#  'sub_002_ch_ECOG_RIGHT_5.p',
#  'sub_010_ch_ECOG_LEFT_1.p',
#  'sub_005_ch_ECOG_RIGHT_2.p',
#  'sub_011_ch_ECOG_LEFT_2.p',
#  'sub_004_ch_ECOG_LEFT_5.p',
#  'sub_006_ch_ECOG_RIGHT_24.p',
#  'sub_010_ch_STN_LEFT_1.p',
#  'sub_010_ch_ECOG_RIGHT_3.p',
#  'sub_001_ch_ECOG_LEFT_6.p',
#  'sub_004_ch_ECOG_RIGHT_6.p',
#  'sub_015_ch_ECOG_LEFT_8.p',
#  'sub_006_ch_ECOG_LEFT_34.p',
#  'sub_006_ch_ECOG_RIGHT_11.p',
#  'sub_003_ch_ECOG_RIGHT_1.p',
#  'sub_008_ch_ECOG_LEFT_4.p',
#  'sub_015_ch_ECOG_LEFT_2.p',
#  'sub_007_ch_STN_LEFT_2.p',
#  'sub_012_ch_ECOG_RIGHT_0.p',
#  'sub_006_ch_ECOG_LEFT_11.p',
#  'sub_006_ch_ECOG_RIGHT_5.p',
#  'sub_001_ch_ECOG_RIGHT_17.p',
#  'sub_000_ch_STN_RIGHT_0.p',
#  'sub_001_ch_ECOG_RIGHT_8.p',
#  'sub_006_ch_ECOG_RIGHT_34.p',
#  'sub_001_ch_ECOG_RIGHT_2.p',
#  'sub_001_ch_ECOG_LEFT_16.p',
#  'sub_003_ch_ECOG_LEFT_0.p',
#  'sub_014_ch_STN_RIGHT_0.p',
#  'sub_003_ch_ECOG_LEFT_4.p',
#  'sub_001_ch_ECOG_RIGHT_19.p',
#  'sub_006_ch_ECOG_RIGHT_30.p',
#  'sub_001_ch_ECOG_RIGHT_6.p',
#  'sub_001_ch_ECOG_LEFT_12.p',
#  'sub_006_ch_ECOG_LEFT_15.p',
#  'sub_006_ch_ECOG_RIGHT_1.p',
#  'sub_012_ch_ECOG_RIGHT_4.p',
#  'sub_001_ch_STN_LEFT_1.p',
#  'sub_001_ch_ECOG_LEFT_18.p',
#  'sub_001_ch_ECOG_RIGHT_13.p',
#  'sub_006_ch_ECOG_RIGHT_15.p',
#  'sub_001_ch_ECOG_LEFT_8.p',
#  'sub_015_ch_ECOG_LEFT_6.p',
#  'sub_003_ch_STN_LEFT_0.p',
#  'sub_003_ch_ECOG_RIGHT_5.p',
#  'sub_008_ch_ECOG_LEFT_0.p',
#  'sub_001_ch_ECOG_LEFT_2.p',
#  'sub_008_ch_STN_LEFT_2.p',
#  'sub_009_ch_ECOG_LEFT_3.p',
#  'sub_004_ch_ECOG_RIGHT_2.p',
#  'sub_003_ch_STN_RIGHT_1.p',
#  'sub_006_ch_ECOG_LEFT_30.p']

# %%
df.keys()
# Out:
# Index(['MOV_TYPE', 'decay_steepness', 'decay_time', 'interval', 'label',
#        'peak_idx_left', 'peak_idx_right', 'peak_left', 'peak_right',
#        'prominence', 'rise_steepness', 'rise_time', 'sharpness', 'slope_ratio',
#        'trough', 'trough_idx', 'width', 'y_contra', 'y_ipsi'],
#       dtype='object')

# %%
# important here: run through all peaks and troughs, estimale the Dkl for every measure 
# get the coordinates, save the DKL parameters for con and ips, plot them
# repeat the same for peaks, estimate the sharpness_ratio

# %%
subjects = ['000', '001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '012', '013', '014', '015']

# %%
d_ALL = {}
for sub in subjects:
    res = np.load(os.path.join(PATH_COMBINED, [f for f in files_combined if sub in f][0]), allow_pickle=True)
    for loc in ["ECOG", "STN"]:
        files = np.sort(np.array([f for f in files_ if loc in f and sub in f]))
        for f in files:
            
            #try:
            d_ch = {}
            ch_ = f[11:-2] # 'sub_000_ch_STN_RIGHT_2.p'
            #if os.path.exists(os.path.join(PATH_SAVE, sub+'_'+ch_+'.p')):
            #    continue
            df_TROUGHS = np.load(os.path.join(PATH_TROUGHS, f), allow_pickle=True)
            df_PEAKS = np.load(os.path.join(PATH_PEAKS, f), allow_pickle=True)

            print(f)


            for idx_df, df_used in enumerate([df_TROUGHS, df_PEAKS]):
                df_CON = {}; df_IPS = {}
                if idx_df == 0:
                    dict_metrics = dict_metrics_TROUGH
                else:
                    dict_metrics = dict_metrics_PEAK
                fig = plt.figure(figsize=(18,8))
                for idx, metric in enumerate(dict_metrics.items()):
                    plt.subplot(2, 5, idx+1)
                    dkl_con, dkl_ips = plot_hist_comp(metric[0], metric[1], df_used)
                    #dkl_con, dkl_ips = plot_hist_comp(metric[0], metric[1], df_used)
                    df_CON[metric] = dkl_con
                    df_IPS[metric] = dkl_ips
                if idx_df == 0:
                    print("TROUGHS")
                    d_ch["TROUGHS_CON"] = df_CON
                    d_ch["TROUGHS_IPS"] = df_IPS
                else:
                    print("PEAKS")
                    d_ch["PEAKS_CON"] = df_CON
                    d_ch["PEAKS_IPS"] = df_IPS
                plt.tight_layout()
                plt.show()

            sharpness_ratio_CON = get_sharpness_ratio(df_PEAKS, df_TROUGHS, MOV_TYPE="CON")
            sharpness_ratio_IPS = get_sharpness_ratio(df_PEAKS, df_TROUGHS, MOV_TYPE="IPS")
            sharpness_ratio_NO_MOV = get_sharpness_ratio(df_PEAKS, df_TROUGHS, MOV_TYPE="NO_MOV")

            d_ch["sharpness_ratio_CON"] = sharpness_ratio_CON
            d_ch["sharpness_ratio_IPS"] = sharpness_ratio_IPS
            d_ch["sharpness_ratio_NO_MOV"] = sharpness_ratio_NO_MOV

            d_ch["TROUGHS_COUNT_NO_MOV"] = df_TROUGHS[df_TROUGHS.MOV_TYPE == "NO_MOV"].count()[0]
            d_ch["TROUGHS_COUNT_CON"] = df_TROUGHS[df_TROUGHS.MOV_TYPE == "CON"].count()[0]
            d_ch["TROUGHS_COUNT_IPS"] = df_TROUGHS[df_TROUGHS.MOV_TYPE == "IPS"].count()[0]
            d_ch["TROUGHS_ratio_CON"] = d_ch["TROUGHS_COUNT_CON"] / d_ch["TROUGHS_COUNT_NO_MOV"]
            d_ch["TROUGHS_ratio_IPS"] = d_ch["TROUGHS_COUNT_IPS"] / d_ch["TROUGHS_COUNT_NO_MOV"]

            d_ch["PEAKS_COUNT_NO_MOV"] = df_PEAKS[df_PEAKS.MOV_TYPE == "NO_MOV"].count()[0]
            d_ch["PEAKS_COUNT_CON"] = df_PEAKS[df_PEAKS.MOV_TYPE == "CON"].count()[0]
            d_ch["PEAKS_COUNT_IPS"] = df_PEAKS[df_PEAKS.MOV_TYPE == "IPS"].count()[0]
            d_ch["PEAKS_ratio_CON"] = d_ch["PEAKS_COUNT_CON"] / d_ch["PEAKS_COUNT_NO_MOV"]
            d_ch["PEAKS_ratio_IPS"] = d_ch["PEAKS_COUNT_IPS"] / d_ch["PEAKS_COUNT_NO_MOV"]

            d_ch["coords"] = res[ch_]["coords"]
            d_ch["ratio_con_all"] = np.where(res[ch_]["mov_con"]>0)[0].shape[0] / \
                    np.where((res[ch_]["mov_con"]==0) & (res[ch_]["mov_ips"]==0))[0].shape[0]
            d_ch["ratio_ips_all"] = np.where(res[ch_]["mov_ips"]>0)[0].shape[0] / \
                    np.where((res[ch_]["mov_ips"]==0) & (res[ch_]["mov_ips"]==0))[0].shape[0]


            with open(os.path.join(PATH_SAVE, sub+'_'+ch_+'.p'), 'wb') as f:
                pickle.dump(d_ch, f, pickle.HIGHEST_PROTOCOL)

            d_ALL[ch] = d_ch
            #except:
            #    print("CANNOT EVALUATE: ")
            #    print(f)
# Out:
# sub_000_ch_ECOG_RIGHT_0.p
# TROUGHS
# PEAKS
# sub_000_ch_ECOG_RIGHT_1.p
# TROUGHS
# PEAKS
# sub_000_ch_ECOG_RIGHT_2.p
# TROUGHS
# PEAKS
# sub_000_ch_ECOG_RIGHT_3.p
# TROUGHS
# PEAKS
# sub_000_ch_ECOG_RIGHT_4.p
# TROUGHS
# PEAKS
# sub_000_ch_ECOG_RIGHT_5.p
# TROUGHS
# PEAKS
# sub_000_ch_STN_RIGHT_0.p
# TROUGHS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-172-5a9cb4071fe3> in <module>
#      26                 for idx, metric in enumerate(dict_metrics.items()):
#      27                     plt.subplot(2, 5, idx+1)
# ---> 28                     dkl_con, dkl_ips = plot_hist_comp(metric[0], metric[1], df_used)
#      29                     #dkl_con, dkl_ips = plot_hist_comp(metric[0], metric[1], df_used)
#      30                     df_CON[metric] = dkl_con
#
# <ipython-input-158-bf20eabe86f1> in plot_hist_comp(metric, metric_unit, df)
#      33     p = np.array(df[df.MOV_TYPE.str.contains("NO_MOV")][metric])
#      34     q_con = np.array(df[df.MOV_TYPE.str.contains("CON")][metric])
# ---> 35     q_ips = np.array(df[df.MOV_TYPE.str.contains("IPS")][metric])
#      36
#      37     range_ = [np.min(np.concatenate([q_con, q_ips, p])), np.max(np.concatenate([q_con, q_ips, p]))]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1841                 )
#    1842                 raise TypeError(msg)
# -> 1843             return func(self, *args, **kwargs)
#    1844
#    1845         wrapper.__name__ = func_name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in contains(self, pat, case, flags, na, regex)
#    2700     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    2701         result = str_contains(
# -> 2702             self._parent, pat, case=case, flags=flags, na=na, regex=regex
#    2703         )
#    2704         return self._wrap_result(result, fill_value=na)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in str_contains(arr, pat, case, flags, na, regex)
#     361             uppered = _na_map(lambda x: x.upper(), arr)
#     362             return _na_map(f, uppered, na, dtype=bool)
# --> 363     return _na_map(f, arr, na, dtype=bool)
#     364
#     365
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in _na_map(f, arr, na_result, dtype)
#     103 def _na_map(f, arr, na_result=np.nan, dtype=object):
#     104     # should really _check_ for NA
# --> 105     return _map(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     106
#     107
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in _map(f, arr, na_mask, na_value, dtype)
#     118         try:
#     119             convert = not all(mask)
# --> 120             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#     121         except (TypeError, AttributeError) as e:
#     122             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/strings.py in <lambda>(x)
#     352             )
#     353
# --> 354         f = lambda x: bool(regex.search(x))
#     355     else:
#     356         if case:
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fae0856f710> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#    1083         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
# -> 1414             self._copy_tick_props(self.majorTicks[0], tick)
#    1415
#    1416         return self.majorTicks[:numticks]
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in _copy_tick_props(self, src, dest)
#    1379         dest.label2.update_from(src.label2)
#    1380         dest.tick1line.update_from(src.tick1line)
# -> 1381         dest.tick2line.update_from(src.tick2line)
#    1382         dest.gridline.update_from(src.gridline)
#    1383
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in update_from(self, other)
#    1347         self._linestyle = other._linestyle
#    1348         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1349                                    other._marker.get_fillstyle())
#    1350         self._drawstyle = other._drawstyle
#    1351
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/markers.py in _set_tickright(self)
#     753
#     754     def _set_tickright(self):
# --> 755         self._transform = Affine2D().scale(1.0, 1.0)
#     756         self._snap_threshold = 1.0
#     757         self._filled = False
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fae085ff0e0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     115         # ignore the tracking, just draw and close all figures
#     116         try:
# --> 117             return show(True)
#     118         except Exception as e:
#     119             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </Users/hi/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/legend.py in draw(self, renderer)
#     668             self.legendPatch.draw(renderer)
#     669
# --> 670         self._legend_box.draw(renderer)
#     671
#     672         renderer.close_group('legend')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/offsetbox.py in draw(self, renderer)
#     254                                                         renderer)
#     255
# --> 256         px, py = self.get_offset(width, height, xdescent, ydescent, renderer)
#     257
#     258         for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/offsetbox.py in get_offset(self, width, height, xdescent, ydescent, renderer)
#     194         """
#     195         return (self._offset(width, height, xdescent, ydescent, renderer)
# --> 196                 if callable(self._offset)
#     197                 else self._offset)
#     198
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/legend.py in _findoffset(self, width, height, xdescent, ydescent, renderer)
#     625
#     626         if self._loc == 0:  # "best".
# --> 627             x, y = self._find_best_position(width, height, renderer)
#     628         elif self._loc in Legend.codes.values():  # Fixed location.
#     629             bbox = Bbox.from_bounds(0, 0, width, height)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/legend.py in _find_best_position(self, width, height, renderer, consider)
#    1124         assert self.isaxes
#    1125
# -> 1126         verts, bboxes, lines, offsets = self._auto_legend_data()
#    1127         if self._loc_used_default and verts.shape[0] > 200000:
#    1128             # this size results in a 3+ second render time on a good machine
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/legend.py in _auto_legend_data(self)
#     918             if isinstance(handle, Rectangle):
#     919                 transform = handle.get_data_transform()
# --> 920                 bboxes.append(handle.get_bbox().transformed(transform))
#     921             else:
#     922                 transform = handle.get_transform()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py in transformed(self, transform)
#     513         ll, ul, lr = transform.transform(np.array([pts[0],
#     514             [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
# --> 515         return Bbox([ll, [lr[0], ul[1]]])
#     516
#     517     def inverse_transformed(self, transform):
#
# KeyboardInterrupt:
