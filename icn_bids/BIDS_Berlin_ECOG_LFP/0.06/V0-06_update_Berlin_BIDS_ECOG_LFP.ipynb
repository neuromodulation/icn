# %%
import os

import mne
import mne_bids

# %%
def get_all_files(path, suffix, get_bids=False, prefix=None, bids_root=None, verbose=False, extension=None):
    """Return all files in all (sub-)directories of path with given suffixes and prefixes (case-insensitive).

    Args:
        path (string)
        suffix (iterable): e.g. ["vhdr", "edf"] or ".json"
        get_bids (boolean): True if BIDS_Path type should be returned instead of string. Default: False
        bids_root (string/path): Path of BIDS root folder. Only required if get_bids=True.
        prefix (iterable): e.g. ["SelfpacedRota", "ButtonPress] (optional)

    Returns:
        filepaths (list of strings or list of BIDS_Path)
    """

    if isinstance(suffix, str):
        suffix = [suffix]
    if isinstance(prefix, str):
        prefix = [prefix]

    filepaths = []
    for root, dirs, files in os.walk(path):
        for file in files:
            for suff in suffix:
                if file.endswith(suff.lower()):
                    if not prefix:
                        filepaths.append(os.path.join(root, file))
                    else:
                        for pref in prefix:
                            if pref.lower() in file.lower():
                                filepaths.append(os.path.join(root, file))

    bids_paths = filepaths
    if get_bids:
        if not bids_root:
            print("Warning: No root folder given. Please pass bids_root parameter to create a complete BIDS_Path object.")
        bids_paths = []
        for filepath in filepaths:
            entities = mne_bids.get_entities_from_fname(filepath)
            try:
                bids_path = mne_bids.BIDSPath(subject=entities["subject"], session=entities["session"], task=entities["task"], run=entities["run"], acquisition=entities["acquisition"], suffix=entities["suffix"], extension=extension, root=bids_root)
            except ValueError as err:
                print(f"ValueError while creating BIDS_Path object for file {filepath}: {err}")
            else:
                bids_paths.append(bids_path)

    if verbose:
        if not bids_paths:
            print("No corresponding files found.")
        else:    
            print('Corresponding files found:')
            for idx, file in enumerate(bids_paths):
                print(idx, ':', os.path.basename(file))
                
    return bids_paths

# %%
root = r'C:\Users\richa\OneDrive - Charité - Universitätsmedizin Berlin\Data\BIDS_Berlin_ECOG_LFP\rawdata'
files = get_all_files(
    path=root,
    suffix='ieeg.json',
    get_bids=True,
    prefix=None,
    bids_root=root,
    verbose=True,
    extension='json')
# Out:
# Corresponding files found:
# 0 : sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.json
# 1 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# 2 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# 3 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.json
# 4 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_ieeg.json
# 5 : sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_ieeg.json
# 6 : sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_ieeg.json
# 7 : sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_ieeg.json
# 8 : sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_ieeg.json
# 9 : sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# 10 : sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.json
# 11 : sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_ieeg.json
# 12 : sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_ieeg.json
# 13 : sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 14 : sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_ieeg.json
# 15 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# 16 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.json
# 17 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.json
# 18 : sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# 19 : sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# 20 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.json
# 21 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_ieeg.json
# 22 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_ieeg.json
# 23 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.json
# 24 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_ieeg.json
# 25 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_ieeg.json
# 26 : sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 27 : sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_ieeg.json
# 28 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_ieeg.json
# 29 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_ieeg.json
# 30 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_ieeg.json
# 31 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_ieeg.json
# 32 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_ieeg.json
# 33 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_ieeg.json
# 34 : sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 35 : sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.json
# 36 : sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 37 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# 38 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# 39 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_ieeg.json
# 40 : sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 41 : sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# 42 : sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_ieeg.json
# 43 : sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# 44 : sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_ieeg.json
# 45 : sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# 46 : sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_ieeg.json
# 47 : sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 48 : sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# 49 : sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 50 : sub-004_ses-EphysMedOff01_task-RestTransition_acq-StimOff_run-01_ieeg.json
# 51 : sub-004_ses-EphysMedOff01_task-RestTransition_acq-StimOff_run-02_ieeg.json
# 52 : sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# 53 : sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# 54 : sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# 55 : sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 56 : sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_ieeg.json
# 57 : sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# 58 : sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# 59 : sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 60 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# 61 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.json
# 62 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.json
# 63 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_ieeg.json
# 64 : sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# 65 : sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 66 : sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_ieeg.json
# 67 : sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# 68 : sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 69 : sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.json
# 70 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# 71 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.json
# 72 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.json
# 73 : sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# 74 : sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 75 : sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.json
# 76 : sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.json
# 77 : sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# 78 : sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 79 : sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.json
# 80 : sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# 81 : sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_ieeg.json
# 82 : sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_ieeg.json
# 83 : sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.json
# 84 : sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.json
# 85 : sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_ieeg.json
# 86 : sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.json
# 87 : sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_ieeg.json
# 88 : sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.json
# 89 : sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.json
# 90 : sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.json
# 91 : sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.json
# 92 : sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.json
# 93 : sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.json
# 94 : sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.json
# 95 : sub-005_ses-EphysMedOn01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.json
# 96 : sub-005_ses-EphysMedOn01_task-Transition_acq-StimOff_run-01_ieeg.json
# 97 : sub-005_ses-EphysMedOn01_task-UPDRSIII_acq-StimOff_run-01_ieeg.json
# 98 : sub-005_ses-EphysMedOn02_task-BlockRotationL_acq-StimOn_run-01_ieeg.json
# 99 : sub-005_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.json
# 100 : sub-005_ses-EphysMedOn02_task-Evoked_acq-StimOn_run-01_ieeg.json
# 101 : sub-005_ses-EphysMedOn02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.json
# 102 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.json
# 103 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.json
# 104 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.json
# 105 : sub-005_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.json
# 106 : sub-005_ses-EphysMedOn02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.json

# %%
import json

# %%
for file in files:
    with open(file.fpath) as json_file:
        ieeg_json = json.load(json_file)
    mne_bids.update_sidecar_json(file, {'iEEGElectrodeGroups': str(ieeg_json['iEEGElectrodeGroups'])})

# %%
raw_files = get_all_files(
    path=root,
    suffix='vhdr',
    get_bids=True,
    prefix=None,
    bids_root=root,
    verbose=True,
    extension='vhdr')
# Out:
# Corresponding files found:
# 0 : sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.vhdr
# 1 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 2 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 3 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 4 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# 5 : sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_ieeg.vhdr
# 6 : sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_ieeg.vhdr
# 7 : sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_ieeg.vhdr
# 8 : sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_ieeg.vhdr
# 9 : sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 10 : sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 11 : sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_ieeg.vhdr
# 12 : sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_ieeg.vhdr
# 13 : sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 14 : sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_ieeg.vhdr
# 15 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 16 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 17 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# 18 : sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 19 : sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 20 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.vhdr
# 21 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_ieeg.vhdr
# 22 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_ieeg.vhdr
# 23 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 24 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 25 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# 26 : sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 27 : sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_ieeg.vhdr
# 28 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 29 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 30 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# 31 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_ieeg.vhdr
# 32 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 33 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# 34 : sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 35 : sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vhdr
# 36 : sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 37 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 38 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 39 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# 40 : sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 41 : sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# 42 : sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_ieeg.vhdr
# 43 : sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 44 : sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_ieeg.vhdr
# 45 : sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# 46 : sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 47 : sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 48 : sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# 49 : sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 50 : sub-004_ses-EphysMedOff01_task-RestTransition_acq-StimOff_run-01_ieeg.vhdr
# 51 : sub-004_ses-EphysMedOff01_task-RestTransition_acq-StimOff_run-02_ieeg.vhdr
# 52 : sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 53 : sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 54 : sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# 55 : sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 56 : sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_ieeg.vhdr
# 57 : sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# 58 : sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# 59 : sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 60 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 61 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 62 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_ieeg.vhdr
# 63 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_ieeg.vhdr
# 64 : sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# 65 : sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 66 : sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_ieeg.vhdr
# 67 : sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# 68 : sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 69 : sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vhdr
# 70 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 71 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 72 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# 73 : sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# 74 : sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 75 : sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 76 : sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_ieeg.vhdr
# 77 : sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# 78 : sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 79 : sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.vhdr
# 80 : sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# 81 : sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_ieeg.vhdr
# 82 : sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vhdr
# 83 : sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_ieeg.vhdr
# 84 : sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.vhdr
# 85 : sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_ieeg.vhdr
# 86 : sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 87 : sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 88 : sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vhdr
# 89 : sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vhdr
# 90 : sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_ieeg.vhdr
# 91 : sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_ieeg.vhdr
# 92 : sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 93 : sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_ieeg.vhdr
# 94 : sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_ieeg.vhdr
# 95 : sub-005_ses-EphysMedOn01_task-SelfpacedSpeech_acq-StimOff_run-01_ieeg.vhdr
# 96 : sub-005_ses-EphysMedOn01_task-Transition_acq-StimOff_run-01_ieeg.vhdr
# 97 : sub-005_ses-EphysMedOn01_task-UPDRSIII_acq-StimOff_run-01_ieeg.vhdr
# 98 : sub-005_ses-EphysMedOn02_task-BlockRotationL_acq-StimOn_run-01_ieeg.vhdr
# 99 : sub-005_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_ieeg.vhdr
# 100 : sub-005_ses-EphysMedOn02_task-Evoked_acq-StimOn_run-01_ieeg.vhdr
# 101 : sub-005_ses-EphysMedOn02_task-ReadRelaxMoveL_acq-StimOff_run-01_ieeg.vhdr
# 102 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_ieeg.vhdr
# 103 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_ieeg.vhdr
# 104 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_ieeg.vhdr
# 105 : sub-005_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_ieeg.vhdr
# 106 : sub-005_ses-EphysMedOn02_task-SelfpacedRotationR_acq-StimOn_run-01_ieeg.vhdr

# %% [markdown]
# # See if all files can still be read

# %%
for file in raw_files:
    mne_bids.read_raw_bids(file, verbose=False)

# %%
tasks = {
    "SelfpacedSpeech": "Selfpaced Speech", 
    "SelfpacedRotationR": "Selfpaced Rotation R",
    "SelfpacedRotationL": "Selfpaced Rotation L",
    "BlockRotationR": "Block Rotation R",
    "BlockRotationL": "Block Rotation L",
    "UPDRSIII": "UPDRS-III",
    "ReadRelaxMoveL": "Read Relax Move L"}

for file in files:
    with open(file.fpath) as json_file:
        ieeg_json = json.load(json_file)
    if ieeg_json['TaskName'] in tasks.keys():
        mne_bids.update_sidecar_json(file, {'TaskName': tasks[ieeg_json['TaskName']]})

# %% [markdown]
# ### Updated coordsystems from "mni" to "MNI152NLin2009bAsym" using regex tool

# %% [markdown]
# ### Now check if data still works

# %%
for file in raw_files:
    mne_bids.read_raw_bids(file, verbose=False)

# %%
raw = mne_bids.read_raw_bids(raw_files[0], verbose=False)
# Out:
# Extracting parameters from C:\Users\richa\OneDrive - Charité - Universitätsmedizin Berlin\Data\BIDS_Berlin_ECOG_LFP\rawdata\sub-001\ses-EphysMedOff01\ieeg\sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_ieeg.vhdr...
# Setting channel info structure...
# Reading channel info from C:\Users\richa\OneDrive - Charité - Universitätsmedizin Berlin\Data\BIDS_Berlin_ECOG_LFP\rawdata\sub-001\ses-EphysMedOff01\ieeg\sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_channels.tsv.
# Reading electrode coords from C:\Users\richa\OneDrive - Charité - Universitätsmedizin Berlin\Data\BIDS_Berlin_ECOG_LFP\rawdata\sub-001\ses-EphysMedOff01\ieeg\sub-001_ses-EphysMedOff01_space-mni_electrodes.tsv.
# c:\users\richa\github\mne-bids\mne_bids\path.py:1092: RuntimeWarning: Did not find any events.tsv associated with sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01.
#
# The search_str was "C:\Users\richa\OneDrive - Charité - Universitätsmedizin Berlin\Data\BIDS_Berlin_ECOG_LFP\rawdata\sub-001\**\sub-001_ses-EphysMedOff01*events.tsv"
#   warn(msg)
# c:\users\richa\github\mne-bids\mne_bids\dig.py:468: RuntimeWarning: Defaulting coordinate frame to unknown from coordinate system input Other
#   warn(f"Defaulting coordinate frame to unknown "
# c:\users\richa\github\mne-bids\mne_bids\dig.py:519: RuntimeWarning: Fiducial point nasion not found, assuming identity unknown to head transformation
#   raw.set_montage(montage, on_missing='warn', verbose=verbose)
# c:\users\richa\github\mne-bids\mne_bids\dig.py:519: RuntimeWarning: DigMontage is only a subset of info. There are 8 channel positions not present in the DigMontage. The required channels are:
#
# ['LFP_L_1_2_STN_B', 'LFP_L_1_3_STN_B', 'LFP_L_1_4_STN_B', 'LFP_L_1_5_STN_B', 'LFP_L_1_6_STN_B', 'LFP_L_1_7_STN_B', 'LFP_L_1_8_STN_B', 'LFP_R_1_8_STN_B'].
#
# Consider using inst.set_channel_types if these are not EEG channels, or use the on_missing parameter if the channel positions are allowed to be unknown in your analyses.
#   raw.set_montage(montage, on_missing='warn', verbose=verbose)

# %%
raw.info
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: ANALOG_R_ROTA_C, ECOG_L_1_2_SMC_, ECOG_L_1_3_SMC_, ...
#  chs: 1 MISC, 5 ECOG, 8 SEEG
#  custom_ref_applied: False
#  dig: 5 items (5 EEG)
#  highpass: 0.0 Hz
#  line_freq: 50
#  lowpass: 2500.0 Hz
#  meas_date: 2017-10-18 09:31:45 UTC
#  nchan: 14
#  projs: []
#  sfreq: 5000.0 Hz
#  subject_info: 25 items (dict)
# >

# %%
raw.info['dig']
# Out:
# [<DigPoint |     EEG #1 : (-46.0, -15.5, 63.0) mm   : head frame>,
#  <DigPoint |     EEG #2 : (-45.5, -5.5, 60.5) mm    : head frame>,
#  <DigPoint |     EEG #3 : (-44.5, 4.0, 57.5) mm     : head frame>,
#  <DigPoint |     EEG #4 : (-42.0, 14.0, 53.5) mm    : head frame>,
#  <DigPoint |     EEG #5 : (-39.0, 22.5, 49.5) mm    : head frame>]

# %% [markdown]
# # Now reorder channels.tsv

# %%
channel_files = get_all_files(
    path=root,
    suffix='channels.tsv',
    get_bids=False,
    prefix=None,
    bids_root=root,
    verbose=True,
    extension='tsv')
# Out:
# Corresponding files found:
# 0 : sub-001_ses-EphysMedOff01_task-BlockRotationR_acq-StimOffOn_run-01_channels.tsv
# 1 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# 2 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# 3 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-01_channels.tsv
# 4 : sub-001_ses-EphysMedOff01_task-Rest_acq-StimOn_run-02_channels.tsv
# 5 : sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOff_run-01_channels.tsv
# 6 : sub-001_ses-EphysMedOff01_task-Visuomotor_acq-StimOn_run-01_channels.tsv
# 7 : sub-001_ses-EphysMedOn01_task-BlockRotationWheel_acq-StimOff_run-01_channels.tsv
# 8 : sub-001_ses-EphysMedOn01_task-FreeDrawing_acq-StimOff_run-01_channels.tsv
# 9 : sub-001_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# 10 : sub-001_ses-EphysMedOn01_task-Rest_acq-StimOn_run-01_channels.tsv
# 11 : sub-001_ses-EphysMedOn01_task-SelfpacedForceWheel_acq-StimOff_run-01_channels.tsv
# 12 : sub-001_ses-EphysMedOn02_task-BlockRotationL_acq-StimOffOn_run-01_channels.tsv
# 13 : sub-001_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 14 : sub-001_ses-EphysMedOn02_task-ContinuousStopping_acq-StimOffOn_run-01_channels.tsv
# 15 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# 16 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_channels.tsv
# 17 : sub-001_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_channels.tsv
# 18 : sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# 19 : sub-002_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# 20 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_channels.tsv
# 21 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-02_channels.tsv
# 22 : sub-002_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-03_channels.tsv
# 23 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_channels.tsv
# 24 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-02_channels.tsv
# 25 : sub-002_ses-EphysMedOff02_task-Rest_acq-StimOff_run-03_channels.tsv
# 26 : sub-002_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 27 : sub-002_ses-EphysMedOff02_task-Speech_acq-StimOff_run-01_channels.tsv
# 28 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-01_channels.tsv
# 29 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-02_channels.tsv
# 30 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-03_channels.tsv
# 31 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOff_run-04_channels.tsv
# 32 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-01_channels.tsv
# 33 : sub-002_ses-EphysMedOff03_task-Rest_acq-StimOn_run-02_channels.tsv
# 34 : sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 35 : sub-002_ses-EphysMedOff03_task-SelfpacedRotationR_acq-StimOn_run-01_channels.tsv
# 36 : sub-003_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 37 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# 38 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# 39 : sub-003_ses-EphysMedOff01_task-Rest_acq-StimOff_run-03_channels.tsv
# 40 : sub-003_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 41 : sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# 42 : sub-003_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-02_channels.tsv
# 43 : sub-003_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# 44 : sub-003_ses-EphysMedOn02_task-RestAndSpeech_acq-StimOff_run-01_channels.tsv
# 45 : sub-003_ses-EphysMedOn02_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# 46 : sub-003_ses-EphysMedOn03_task-Rest_acq-StimOff_run-01_channels.tsv
# 47 : sub-003_ses-EphysMedOn03_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 48 : sub-004_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# 49 : sub-004_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 50 : sub-004_ses-EphysMedOff01_task-RestTransition_acq-StimOff_run-01_channels.tsv
# 51 : sub-004_ses-EphysMedOff01_task-RestTransition_acq-StimOff_run-02_channels.tsv
# 52 : sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# 53 : sub-004_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# 54 : sub-004_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# 55 : sub-004_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 56 : sub-004_ses-EphysMedOff01_task-Speech_acq-StimOff_run-01_channels.tsv
# 57 : sub-004_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# 58 : sub-004_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# 59 : sub-004_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 60 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# 61 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-02_channels.tsv
# 62 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-03_channels.tsv
# 63 : sub-004_ses-EphysMedOn01_task-Rest_acq-StimOff_run-04_channels.tsv
# 64 : sub-004_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# 65 : sub-004_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 66 : sub-004_ses-EphysMedOn01_task-Speech_acq-StimOff_run-01_channels.tsv
# 67 : sub-004_ses-EphysMedOn02_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# 68 : sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 69 : sub-004_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_channels.tsv
# 70 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# 71 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_channels.tsv
# 72 : sub-004_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_channels.tsv
# 73 : sub-005_ses-EphysMedOff01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# 74 : sub-005_ses-EphysMedOff01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 75 : sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-01_channels.tsv
# 76 : sub-005_ses-EphysMedOff01_task-Rest_acq-StimOff_run-02_channels.tsv
# 77 : sub-005_ses-EphysMedOff01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# 78 : sub-005_ses-EphysMedOff01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 79 : sub-005_ses-EphysMedOff01_task-SelfpacedSpeech_acq-StimOff_run-01_channels.tsv
# 80 : sub-005_ses-EphysMedOff01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# 81 : sub-005_ses-EphysMedOff02_task-BlockRotationL_acq-StimOn_run-01_channels.tsv
# 82 : sub-005_ses-EphysMedOff02_task-BlockRotationR_acq-StimOn_run-01_channels.tsv
# 83 : sub-005_ses-EphysMedOff02_task-Evoked_acq-StimOn_run-01_channels.tsv
# 84 : sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOff_run-01_channels.tsv
# 85 : sub-005_ses-EphysMedOff02_task-ReadRelaxMoveL_acq-StimOn_run-01_channels.tsv
# 86 : sub-005_ses-EphysMedOff02_task-Rest_acq-StimOff_run-01_channels.tsv
# 87 : sub-005_ses-EphysMedOff02_task-Rest_acq-StimOn_run-01_channels.tsv
# 88 : sub-005_ses-EphysMedOff02_task-SelfpacedRotationL_acq-StimOn_run-01_channels.tsv
# 89 : sub-005_ses-EphysMedOff02_task-SelfpacedRotationR_acq-StimOn_run-01_channels.tsv
# 90 : sub-005_ses-EphysMedOn01_task-BlockRotationL_acq-StimOff_run-01_channels.tsv
# 91 : sub-005_ses-EphysMedOn01_task-BlockRotationR_acq-StimOff_run-01_channels.tsv
# 92 : sub-005_ses-EphysMedOn01_task-Rest_acq-StimOff_run-01_channels.tsv
# 93 : sub-005_ses-EphysMedOn01_task-SelfpacedRotationL_acq-StimOff_run-01_channels.tsv
# 94 : sub-005_ses-EphysMedOn01_task-SelfpacedRotationR_acq-StimOff_run-01_channels.tsv
# 95 : sub-005_ses-EphysMedOn01_task-SelfpacedSpeech_acq-StimOff_run-01_channels.tsv
# 96 : sub-005_ses-EphysMedOn01_task-Transition_acq-StimOff_run-01_channels.tsv
# 97 : sub-005_ses-EphysMedOn01_task-UPDRSIII_acq-StimOff_run-01_channels.tsv
# 98 : sub-005_ses-EphysMedOn02_task-BlockRotationL_acq-StimOn_run-01_channels.tsv
# 99 : sub-005_ses-EphysMedOn02_task-BlockRotationR_acq-StimOn_run-01_channels.tsv
# 100 : sub-005_ses-EphysMedOn02_task-Evoked_acq-StimOn_run-01_channels.tsv
# 101 : sub-005_ses-EphysMedOn02_task-ReadRelaxMoveL_acq-StimOff_run-01_channels.tsv
# 102 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOff_run-01_channels.tsv
# 103 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOn_run-01_channels.tsv
# 104 : sub-005_ses-EphysMedOn02_task-Rest_acq-StimOn_run-02_channels.tsv
# 105 : sub-005_ses-EphysMedOn02_task-SelfpacedRotationL_acq-StimOn_run-01_channels.tsv
# 106 : sub-005_ses-EphysMedOn02_task-SelfpacedRotationR_acq-StimOn_run-01_channels.tsv

# %%
import pandas as pd

# %%
dfs = list()
for file in channel_files:
    df = pd.read_csv(file, sep='\t', index_col=0)
    dfs.append(df)

# %%
dfs[0].columns
# Out:
# Index(['type', 'units', 'low_cutoff', 'high_cutoff', 'description',
#        'sampling_frequency', 'status', 'status_description'],
#       dtype='object')

# %%
dfs[73].columns
# Out:
# Index(['type', 'units', 'low_cutoff', 'high_cutoff', 'reference', 'group',
#        'sampling_frequency', 'notch', 'status', 'status_description'],
#       dtype='object')

# %%
for i, df in enumerate(dfs):
    if 'group' in df.columns:
        df_reorder = df[['type', 'units', 'low_cutoff', 'high_cutoff',
                         'reference', 'group', 'sampling_frequency', 
                         'notch', 'status', 'status_description']]
        df_reorder.to_csv(channel_files[i], sep='\t', na_rep='n/a', index=True)

# %%
for i, df in enumerate(dfs):
    if 'group' not in df.columns:
        df['group'] = None
        if 'reference' not in df.columns:
            df['reference'] = None
            if 'notch' not in df.columns:
                df['notch'] = None
        df_reorder = df[['type', 'units', 'low_cutoff', 'high_cutoff',
                         'reference', 'group', 'sampling_frequency', 
                         'notch', 'status', 'status_description']]
        df_reorder.to_csv(channel_files[i], sep='\t', na_rep='n/a', index=True)

# %%
dfs_new = list()
for file in channel_files:
    df = pd.read_csv(file, sep='\t', index_col=0)
    dfs_new.append(df)

# %%
dfs_new[0]
# Out:
#                  type units  low_cutoff  high_cutoff  reference  group  \
# name
# ANALOG_R_ROTA_C  MISC    µV         0.0       2500.0        NaN    NaN
# ECOG_L_1_2_SMC_  ECOG    µV         0.0       2500.0        NaN    NaN
# ECOG_L_1_3_SMC_  ECOG    µV         0.0       2500.0        NaN    NaN
# ECOG_L_1_4_SMC_  ECOG    µV         0.0       2500.0        NaN    NaN
# ECOG_L_1_5_SMC_  ECOG    µV         0.0       2500.0        NaN    NaN
# ECOG_L_1_6_SMC_  ECOG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_2_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_3_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_4_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_5_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_6_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_7_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_L_1_8_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
# LFP_R_1_8_STN_B  SEEG    µV         0.0       2500.0        NaN    NaN
#
#                  sampling_frequency  notch status  status_description
# name
# ANALOG_R_ROTA_C              5000.0    NaN   good                 NaN
# ECOG_L_1_2_SMC_              5000.0    NaN   good                 NaN
# ECOG_L_1_3_SMC_              5000.0    NaN   good                 NaN
# ECOG_L_1_4_SMC_              5000.0    NaN   good                 NaN
# ECOG_L_1_5_SMC_              5000.0    NaN   good                 NaN
# ECOG_L_1_6_SMC_              5000.0    NaN   good                 NaN
# LFP_L_1_2_STN_B              5000.0    NaN   good                 NaN
# LFP_L_1_3_STN_B              5000.0    NaN   good                 NaN
# LFP_L_1_4_STN_B              5000.0    NaN   good                 NaN
# LFP_L_1_5_STN_B              5000.0    NaN   good                 NaN
# LFP_L_1_6_STN_B              5000.0    NaN   good                 NaN
# LFP_L_1_7_STN_B              5000.0    NaN   good                 NaN
# LFP_L_1_8_STN_B              5000.0    NaN   good                 NaN
# LFP_R_1_8_STN_B              5000.0    NaN   good                 NaN

# %%
dfs_new[73]
# Out:
#                  type units  low_cutoff  high_cutoff  reference  group  \
# name
# LFP_R_1_STN_MT   SEEG    uV         NaN          NaN        NaN    NaN
# LFP_R_234_STN_M  SEEG    uV         NaN          NaN        NaN    NaN
# LFP_R_567_STN_M  SEEG    uV         NaN          NaN        NaN    NaN
# LFP_R_8_STN_MT   SEEG    uV         NaN          NaN        NaN    NaN
# LFP_L_1_STN_MT   SEEG    uV         NaN          NaN        NaN    NaN
# LFP_L_234_STN_M  SEEG    uV         NaN          NaN        NaN    NaN
# LFP_L_567_STN_M  SEEG    uV         NaN          NaN        NaN    NaN
# LFP_L_8_STN_MT   SEEG    uV         NaN          NaN        NaN    NaN
# ECOG_L_1_SMC_AT  ECOG    uV         NaN          NaN        NaN    NaN
# ECOG_L_2_SMC_AT  ECOG    uV         NaN          NaN        NaN    NaN
# ECOG_L_3_SMC_AT  ECOG    uV         NaN          NaN        NaN    NaN
# ECOG_L_4_SMC_AT  ECOG    uV         NaN          NaN        NaN    NaN
# ECOG_L_5_SMC_AT  ECOG    uV         NaN          NaN        NaN    NaN
# ECOG_L_6_SMC_AT  ECOG    uV         NaN          NaN        NaN    NaN
# EEG_Cz_TM         EEG    uV         NaN          NaN        NaN    NaN
# EEG_Fz_TM         EEG    uV         NaN          NaN        NaN    NaN
# EMG_R_BR_TM       EMG    uV         NaN          NaN        NaN    NaN
# EMG_L_BR_TM       EMG    uV         NaN          NaN        NaN    NaN
# ACC_R_X_D2_TM    MISC    uV         NaN          NaN        NaN    NaN
# ACC_R_Y_D2_TM    MISC    uV         NaN          NaN        NaN    NaN
# ACC_R_Z_D2_TM    MISC    uV         NaN          NaN        NaN    NaN
# ACC_L_X_D2_TM    MISC    uV         NaN          NaN        NaN    NaN
# ACC_L_Y_D2_TM    MISC    uV         NaN          NaN        NaN    NaN
# ACC_L_Z_D2_TM    MISC    uV         NaN          NaN        NaN    NaN
# ANALOG_L_ROTA_C  MISC    uV         NaN          NaN        NaN    NaN
#
#                  sampling_frequency  notch status   status_description
# name
# LFP_R_1_STN_MT                 4000    NaN   good                  NaN
# LFP_R_234_STN_M                4000    NaN   good                  NaN
# LFP_R_567_STN_M                4000    NaN   good                  NaN
# LFP_R_8_STN_MT                 4000    NaN   good                  NaN
# LFP_L_1_STN_MT                 4000    NaN    bad  Reference electrode
# LFP_L_234_STN_M                4000    NaN   good                  NaN
# LFP_L_567_STN_M                4000    NaN   good                  NaN
# LFP_L_8_STN_MT                 4000    NaN   good                  NaN
# ECOG_L_1_SMC_AT                4000    NaN   good                  NaN
# ECOG_L_2_SMC_AT                4000    NaN   good                  NaN
# ECOG_L_3_SMC_AT                4000    NaN   good                  NaN
# ECOG_L_4_SMC_AT                4000    NaN   good                  NaN
# ECOG_L_5_SMC_AT                4000    NaN   good                  NaN
# ECOG_L_6_SMC_AT                4000    NaN   good                  NaN
# EEG_Cz_TM                      4000    NaN   good                  NaN
# EEG_Fz_TM                      4000    NaN   good                  NaN
# EMG_R_BR_TM                    4000    NaN   good                  NaN
# EMG_L_BR_TM                    4000    NaN   good                  NaN
# ACC_R_X_D2_TM                  4000    NaN   good                  NaN
# ACC_R_Y_D2_TM                  4000    NaN   good                  NaN
# ACC_R_Z_D2_TM                  4000    NaN   good                  NaN
# ACC_L_X_D2_TM                  4000    NaN   good                  NaN
# ACC_L_Y_D2_TM                  4000    NaN   good                  NaN
# ACC_L_Z_D2_TM                  4000    NaN   good                  NaN
# ANALOG_L_ROTA_C                4000    NaN   good                  NaN
