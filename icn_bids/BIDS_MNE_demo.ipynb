# %%
import mne_bids
import mne
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### specify BIDS path and run file

# %%
run_file_to_read  = r'sub-002_ses-EphysMedOff01_task-SelfpacedRotation_acq-MedOffStimOff_run-01_ieeg.vhdr'
BIDS_PATH = r'C:\Users\ICN_admin\Charité - Universitätsmedizin Berlin\Interventional Cognitive Neuromodulation - Data\Datasets\BIDS_example'

# %%
entities = mne_bids.get_entities_from_fname(run_file_to_read)

# %%
entities
# Out:
# {'subject': '002',
#  'session': 'EphysMedOff01',
#  'task': 'SelfpacedRotation',
#  'acquisition': 'MedOffStimOff',
#  'run': '01',
#  'processing': None,
#  'space': None,
#  'recording': None,
#  'split': None,
#  'suffix': 'ieeg'}

# %%
bids_path = mne_bids.BIDSPath(subject=entities["subject"], session=entities["session"], task=entities["task"], \
    run=entities["run"], acquisition=entities["acquisition"], datatype="ieeg", root=BIDS_PATH)

# %%
bids_path
# Out:
# BIDSPath(
# root: C:\Users\ICN_admin\Charité - Universitätsmedizin Berlin\Interventional Cognitive Neuromodulation - Data\Datasets\BIDS_example
# datatype: ieeg
# basename: sub-002_ses-EphysMedOff01_task-SelfpacedRotation_acq-MedOffStimOff_run-01)

# %%
raw_arr = mne_bids.read_raw_bids(bids_path)
# Out:
# Extracting parameters from C:\Users\ICN_admin\Charité - Universitätsmedizin Berlin\Interventional Cognitive Neuromodulation - Data\Datasets\BIDS_example\sub-002\ses-EphysMedOff01\ieeg\sub-002_ses-EphysMedOff01_task-SelfpacedRotation_acq-MedOffStimOff_run-01_ieeg.vhdr...
# Setting channel info structure...
# Reading events from C:\Users\ICN_admin\Charité - Universitätsmedizin Berlin\Interventional Cognitive Neuromodulation - Data\Datasets\BIDS_example\sub-002\ses-EphysMedOff01\ieeg\sub-002_ses-EphysMedOff01_task-SelfpacedRotation_acq-MedOffStimOff_run-01_events.tsv.
# Reading channel info from C:\Users\ICN_admin\Charité - Universitätsmedizin Berlin\Interventional Cognitive Neuromodulation - Data\Datasets\BIDS_example\sub-002\ses-EphysMedOff01\ieeg\sub-002_ses-EphysMedOff01_task-SelfpacedRotation_acq-MedOffStimOff_run-01_channels.tsv.
# Reading in coordinate system frame other: None.
# ...

# %% [markdown]
# #### through OneDrive Data is here downloaded

# %% [markdown]
# ### BIDS specifications are automatically read in the MNE RawArray

# %%
raw_arr.info
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: LFP_BS_STN_R_1, LFP_BS_STN_R_2, LFP_BS_STN_R_3, LFP_BS_STN_R_4, ...
#  chs: 16 SEEG, 6 ECOG, 3 MISC, 4 EMG
#  custom_ref_applied: False
#  dig: 22 items (22 EEG)
#  highpass: 0.0 Hz
#  line_freq: 50
#  lowpass: 687.8 Hz
#  meas_date: unspecified
#  nchan: 29
#  projs: []
#  sfreq: 1375.5 Hz
#  subject_info: 4 items (dict)
# >

# %%
raw_arr.info["dig"]
# Out:
# [<DigPoint |     EEG #1 : (-12.3, -17.2, -8.7) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #2 : (-13.1, -16.0, -6.9) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #3 : (-13.5, -17.2, -6.5) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #4 : (-12.4, -16.7, -6.2) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #5 : (-13.7, -15.4, -4.7) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #6 : (-14.2, -16.6, -4.3) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #7 : (-13.0, -16.1, -4.0) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #8 : (-14.3, -15.5, -2.1) mm   : MNI Talairach frame>,
#  <DigPoint |     EEG #9 : (11.8, -14.9, -9.1) mm    : MNI Talairach frame>,
#  <DigPoint |    EEG #10 : (12.4, -13.6, -7.0) mm    : MNI Talairach frame>,
#  <DigPoint |    EEG #11 : (12.0, -14.7, -6.4) mm    : MNI Talairach frame>,
#  <DigPoint |    EEG #12 : (13.1, -14.6, -7.0) mm    : MNI Talairach frame>,
# ...

# %%
raw_arr.plot_sensors()

# %%
raw_arr.plot_psd?

# %%
raw_arr.plot_psd(fmax=400)
# Out:
# No projector specified for this dataset. Please consider the method self.add_proj.
# Effective window size : 1.489 (s)
# No projector specified for this dataset. Please consider the method self.add_proj.
# Effective window size : 1.489 (s)
# <ipython-input-49-75c51a211891>:1: UserWarning: Infinite value in PSD for channel LFP_BS_STN_R_1.
# These channels might be dead.
#   raw_arr.plot_psd(fmax=400, proj=True)

# %%
raw_arr.ch_names
# Out:
# ['LFP_BS_STN_R_1',
#  'LFP_BS_STN_R_2',
#  'LFP_BS_STN_R_3',
#  'LFP_BS_STN_R_4',
#  'LFP_BS_STN_R_5',
#  'LFP_BS_STN_R_6',
#  'LFP_BS_STN_R_7',
#  'LFP_BS_STN_R_8',
#  'LFP_BS_STN_L_1',
#  'LFP_BS_STN_L_2',
#  'LFP_BS_STN_L_3',
#  'LFP_BS_STN_L_4',
#  'LFP_BS_STN_L_5',
#  'LFP_BS_STN_L_6',
#  'LFP_BS_STN_L_7',
#  'LFP_BS_STN_L_8',
#  'ECOG_AT_SM_L_1',
#  'ECOG_AT_SM_L_2',
#  'ECOG_AT_SM_L_3',
#  'ECOG_AT_SM_L_4',
#  'ECOG_AT_SM_L_5',
#  'ECOG_AT_SM_L_6',
#  'EEG_TM_Cz__1',
#  'EEG_TM_Fz__1',
#  'EMG_TM_BR_1',
#  'EMG_TM_BR_2',
#  'EMG_TM_FDI_1',
#  'EMG_TM_FDI_2',
#  'ANALOG_ROTA_R_1']

# %%
raw_arr.get_channel_types()
# Out:
# ['seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'seeg',
#  'ecog',
#  'ecog',
#  'ecog',
#  'ecog',
#  'ecog',
#  'ecog',
#  'misc',
#  'misc',
#  'emg',
#  'emg',
#  'emg',
#  'emg',
#  'misc']

# %%
raw_arr.get_data().shape
# Out:
# (29, 675534)

# %%
# %matplotlib qt
raw_arr.plot(scalings='auto', decim='auto', highpass=0.1, lowpass=200)
# Out:
# Setting up band-pass filter from 0.1 - 2e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 0.10, 200.00 Hz: -6.02, -6.02 dB

# %%
raw_arr.to_data_frame()
# Out:
#           time  LFP_BS_STN_R_1  LFP_BS_STN_R_2  LFP_BS_STN_R_3  \
# 0            0             0.0          7000.0          8000.0
# 1            1             0.0         10000.0          9000.0
# 2            1             0.0          7000.0          7000.0
# 3            2             0.0          4000.0          5000.0
# 4            3             0.0          7000.0          6000.0
# ...        ...             ...             ...             ...
# 675529  491110             0.0        -15000.0         -8000.0
# 675530  491110             0.0        -12000.0         -4000.0
# 675531  491111             0.0        -11000.0         -4000.0
# 675532  491112             0.0         -6000.0          1000.0
# 675533  491112             0.0         -6000.0          2000.0
#
#         LFP_BS_STN_R_4  LFP_BS_STN_R_5  LFP_BS_STN_R_6  LFP_BS_STN_R_7  \
# 0               5000.0         -3000.0         -4000.0          2000.0
# ...
