# %%
import sys

# import file from different folder
sys.path.insert(1, '/Users/hi/Documents/lab_work/icn/icn_m1/write_BIDS/')

import BIDS_from_fieldtrip

# %%
filename = 'fieldtrip_sub-BER02_ROTA_SELFPACED_MASTOID_NEUROMEGA_MED_OFF_STIM_OFF_20200130.mat'
BIDS_path = '/Users/hi/Documents/lab_work/neuer_Patient/BIDS_test/'
subject_id = '016'
session = 'left'
task = 'force'
run = '1'

# %%
BIDS_from_fieldtrip.fieldtrip_to_BIDS(filename, BIDS_path, subject_id, session, task, run)
# Out:
# Creating RawArray with float64 data, n_channels=29, n_times=695827
#     Range : 0 ... 695826 =      0.000 ...   506.055 secs
# Ready.
# /Users/hi/Documents/lab_work/icn/icn_m1/write_BIDS/BIDS_from_fieldtrip.py:19: RuntimeWarning: Importing FieldTrip data without an info dict from the original file. Channel locations, orientations and types will be incorrect. The imported data cannot be used for source analysis, channel interpolation etc.
#   raw = mne.io.read_raw_fieldtrip(filename, None)
# /Users/hi/Documents/lab_work/icn/icn_m1/write_BIDS/BIDS_from_fieldtrip.py:19: RuntimeWarning: The supplied FieldTrip structure does not have an elec or grad field. No channel locations will extracted and the kind of channel might be inaccurate.
#   raw = mne.io.read_raw_fieldtrip(filename, None)
# /Users/hi/Documents/lab_work/icn/icn_m1/write_BIDS/BIDS_from_fieldtrip.py:19: RuntimeWarning: Cannot guess the correct type of channel STNR1. Making it a MISC channel.
# ...
