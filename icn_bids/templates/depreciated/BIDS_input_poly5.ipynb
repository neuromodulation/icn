# %%
 # %reset
# Out:
# Nothing done.

# %% [markdown]
# # Dependencies and Imports

# %% [markdown]
# # Subject-specific information
# make sure to choose the kernel located at python.exe. Local kernel could let the output be printed twice (This has apart form the visuals no further consequences)
#
#
# The variables inserted in this first widget will be used for every session-specific JSON initialized in the upcoming second widget. There is no separate JSON-file saved with only these data.

# %% [markdown]
# # Session-specific and recording-specific information
#
#
# Select Poly5-file to convert and add additional session info. After closing one session, json-file will be saved, and a window for a next session will pop up.
#
#
# Files are currently saved in folder where this script is stored.

# %%
"""
subject 
session + hardware + space + UPDRS + electrode localizations
task  + run + channel names + reference + stimsettings + time of acquisition

1 json file per recording

To Do: electrode size
"""
# Out:
# '\nsubject \nsession + hardware + space + UPDRS + electrode localizations\ntask  + run + channel names + reference + stimsettings + time of acquisition\n\n1 json file per recording\n\nTo Do: electrode size\n'

# %%
import TMSiSDK
from TMSiSDK import *
from TMSiSDK.file_readers import Poly5Reader
file = r"C:\Users\Jonathan\Documents\DATA\PROJECT_BERLIN_Conversion\sourcedata\sub-010\ses-EcogLfpMedOff01\532LO56_MedOff1_Rest_StimOff_1 - 20220207T113556\532LO56_MedOff1_Rest_StimOff_1-20220207T113556.DATA.Poly5"
data = Poly5Reader(file)
# Out:
# Reading file  C:\Users\Jonathan\Documents\DATA\PROJECT_BERLIN_Conversion\sourcedata\sub-010\ses-EcogLfpMedOff01\532LO56_MedOff1_Rest_StimOff_1 - 20220207T113556\532LO56_MedOff1_Rest_StimOff_1-20220207T113556.DATA.Poly5
# 	 Number of samples:  1225770
# 	 Number of channels:  39
# 	 Sample rate: 4000 Hz
# Done reading data.

# %%
data.num_samples
# Out:
# 1225770

# %%
data.num_channels
# Out:
# 39

# %%
data.sample_rate
# Out:
# 4000

# %%
mne.io.Raw(data)
# Out:
# Opening raw data file <TMSiSDK.file_readers.poly5reader.Poly5Reader object at 0x000001ED8E735790>...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-cc78fe7ec979> in <module>
# ----> 1 mne.io.Raw(data)
#
# <decorator-gen-184> in __init__(self, fname, allow_maxshield, preload, verbose)
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\mne\io\fiff\raw.py in __init__(self, fname, allow_maxshield, preload, verbose)
#      77         while next_fname is not None:
#      78             raw, next_fname, buffer_size_sec = \
# ---> 79                 self._read_raw_file(next_fname, allow_maxshield,
#      80                                     preload, do_check_fname)
#      81             do_check_fname = False
#
# <decorator-gen-185> in _read_raw_file(self, fname, allow_maxshield, preload, do_check_fname, verbose)
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\mne\io\fiff\raw.py in _read_raw_file(self, fname, allow_maxshield, preload, do_check_fname, verbose)
#     131         if not _file_like(fname):
#     132             if do_check_fname:
# --> 133                 check_fname(fname, 'raw', (
#     134                     'raw.fif', 'raw_sss.fif', 'raw_tsss.fif', 'raw.fif.gz',
#     135                     'raw_sss.fif.gz', 'raw_tsss.fif.gz', '_meg.fif'))
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\mne\utils\check.py in check_fname(fname, filetype, endings, endings_err)
#      48         Obligatory possible endings for the filename.
#      49     """
# ---> 50     _validate_type(fname, 'path-like', 'fname')
#      51     fname = str(fname)
#      52     if len(endings_err) > 0 and not fname.endswith(endings_err):
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\mne\utils\check.py in _validate_type(item, types, item_name, type_name)
#     386                 type_name[-1] = 'or ' + type_name[-1]
#     387                 type_name = ', '.join(type_name)
# --> 388         raise TypeError('%s must be an instance of %s, got %s instead'
#     389                         % (item_name, type_name, type(item),))
#     390
#
# TypeError: fname must be an instance of path-like, got <class 'TMSiSDK.file_readers.poly5reader.Poly5Reader'> instead

# %%
[ch._Channel__name for ch in data.channels]

ch_names = [ch._Channel__name for ch in data.channels]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-800a4dd80f02> in <module>
# ----> 1 [ch._Channel__name for ch in data.channels]
#       2
#       3 ch_names = [ch._Channel__name for ch in data.channels]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'channels'

# %%
d = mne.io.read_raw( data.readAll)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-fe9f29cad1e3> in <module>
# ----> 1 d = mne.io.read_raw( data.readAll)
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\mne\io\_read_raw.py in read_raw(fname, preload, verbose, **kwargs)
#      78     dedicated reader function (read_raw_xxx) instead.
#      79     """
# ---> 80     ext = "".join(Path(fname).suffixes)
#      81     if ext in readers:
#      82         return readers[ext](fname, preload=preload, verbose=verbose, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\pathlib.py in __new__(cls, *args, **kwargs)
#    1069         if cls is Path:
#    1070             cls = WindowsPath if os.name == 'nt' else PosixPath
# -> 1071         self = cls._from_parts(args, init=False)
#    1072         if not self._flavour.is_supported:
#    1073             raise NotImplementedError("cannot instantiate %r on your system"
#
# ~\AppData\Local\Programs\Python\Python39\lib\pathlib.py in _from_parts(cls, args, init)
#     694         # right flavour.
#     695         self = object.__new__(cls)
# --> 696         drv, root, parts = self._parse_args(args)
#     697         self._drv = drv
#     698         self._root = root
#
# ~\AppData\Local\Programs\Python\Python39\lib\pathlib.py in _parse_args(cls, args)
#     678                 parts += a._parts
#     679             else:
# --> 680                 a = os.fspath(a)
#     681                 if isinstance(a, str):
#     682                     # Force-cast str subclasses to str (issue #21127)
#
# TypeError: expected str, bytes or os.PathLike object, not bool

# %%
from  TMSiSDK import *

from TMSiSDK.file_writer import FileWriter, FileFormat

fil = FileWriter(FileFormat.poly5, file)

fil.open
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-55a57a76f2b0> in <module>
#       5 fil = FileWriter(FileFormat.poly5, file)
#       6
# ----> 7 fil.open()
#
# TypeError: open() missing 1 required positional argument: 'device'

# %%
mne.io.RawArray(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-4e4943d94327> in <module>
# ----> 1 mne.io.RawArray(data)
#
# TypeError: __init__() missing 1 required positional argument: 'info'

# %%
from TMSiSDK.device import DeviceInterfaceType, ChannelType, DeviceState

tmsi_device.initialize()

    # Create the device object to interface with the SAGA-system.
dev = tmsi_device.create(tmsi_device.DeviceType.saga, DeviceInterfaceType.docked, DeviceInterfaceType.usb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a3cf110e4b4f> in <module>
#       1 from TMSiSDK.device import DeviceInterfaceType, ChannelType, DeviceState
#       2
# ----> 3 tmsi_device.initialize()
#       4
#       5     # Create the device object to interface with the SAGA-system.
#
# NameError: name 'tmsi_device' is not defined

# %%
TMSiSDK.get_config(data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-73a9e87ecb3d> in <module>
# ----> 1 TMSiSDK.get_config(data)
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\TMSiSDK\__init__.py in get_config(config_name)
#      30 def get_config(config_name):
#      31
# ---> 32         config_fname = join(configs_dir, config_name + '.xml')
#      33         return config_fname
#
# TypeError: unsupported operand type(s) for +: 'Poly5Reader' and 'str'

# %%
data._readSignalDescription(data,)
ch = data.channels
print(ch)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-a10e0580af7b> in <module>
# ----> 1 data._readSignalDescription(data)
#       2 ch = data.channels
#       3 print(ch)
#
# c:\Users\Jonathan\Documents\VSCODE\.venv\lib\site-packages\TMSiSDK\file_readers\poly5reader.py in _readSignalDescription(self, f)
#     115         chan_list = []
#     116         for ch in range(self.num_channels):
# --> 117             channel_description=struct.unpack("=41p4x11pffffH62x", f.read(136))
#     118             name = channel_description[0][5:].decode('ascii')
#     119             unit_name=channel_description[1].decode('utf-8')
#
# AttributeError: 'Poly5Reader' object has no attribute 'read'

# %%
data._readSignalDescription(data, data.f
# Out:
# <_io.BufferedReader name='C:\\Users\\Jonathan\\Documents\\DATA\\PROJECT_BERLIN_Conversion\\sourcedata\\sub-010\\ses-EcogLfpMedOff01\\532LO56_MedOff1_Rest_StimOff_1 - 20220207T113556\\532LO56_MedOff1_Rest_StimOff_1-20220207T113556.DATA.Poly5'>

# %%
dataraw = np.array(data.samples)
data.sample_rate
# Out:
# 4000

# %%
info = mne.create_info(ch_names=[ch._Channel__name for ch in data.channels], sfreq=data.sample_rate, ch_types=data.num_channels*['misc'])

raw = mne.io.RawArray(data.samples, info)
# Out:
# Creating RawArray with float64 data, n_channels=39, n_times=1225770
#     Range : 0 ... 1225769 =      0.000 ...   306.442 secs
# Ready.
# <ipython-input-13-17d0812adcb0>:1: RuntimeWarning: 1 channel names are too long, have been truncated to 15 characters:
# ['Counter 2power24']
#   info = mne.create_info(ch_names=[ch._Channel__name for ch in data.channels], sfreq=data.sample_rate, ch_types=data.num_channels*['misc'])
# <ipython-input-13-17d0812adcb0>:1: RuntimeWarning: Channel names are not unique, found duplicates for: {'X', 'Y', 'Z'}. Applying running numbers for duplicates.
#   info = mne.create_info(ch_names=[ch._Channel__name for ch in data.channels], sfreq=data.sample_rate, ch_types=data.num_channels*['misc'])

# %%
raw.plot(n_channels=4, title='Data from arrays',
         show=True, block=True)

# %%
sfreq = 1000  # Sampling frequency
times = np.arange(0, 10, 0.001)  # Use 10000 samples (10s)

sin = np.sin(times * 10)  # Multiplied by 10 for shorter phase
cos = np.cos(times * 10)
sinX2 = sin * 2
cosX2 = cos * 2

# Numpy array of size 4 X 10000.
data = np.array(data)

# Definition of channel types and names.
ch_types = ['mag', 'mag', 'grad', 'grad']
ch_names = ['sin', 'cos', 'sinX2', 'cosX2']


# It is also possible to use info from another raw object.
info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=ch_types)

raw = mne.io.RawArray(data, info)

# Scaling of the figure.
# For actual EEG/MEG data different scaling factors should be used.
scalings = {'mag': 2, 'grad': 2}

raw.plot(n_channels=4, scalings=scalings, title='Data from arrays',
         show=True, block=True)
# Out:
# Creating RawArray with float64 data, n_channels=4, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
